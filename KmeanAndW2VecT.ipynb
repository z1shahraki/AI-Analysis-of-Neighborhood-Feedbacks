# %%
# Loading all required packages
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import re
from gensim.models import KeyedVectors
import nltk
import numpy as np

# %%
# Loading Google Word2Vec model 
def read_word2vec(path):
    # Using First 50000 Word2Vecs
    word2vec = KeyedVectors.load_word2vec_format(path, binary=True, limit=50000)
    return word2vec

# %%
# Creating and normalizing word vectors
def average_word_vectors(words, model, vocabulary, num_features):
    # Creating an array of zero values.
    feature_vector = np.zeros((num_features,),dtype="float64")
    nwords = 0.
    # Adding word vectors
    for word in words:
        if word in vocabulary: 
            nwords = nwords + 1.
            feature_vector = np.add(feature_vector, model[word])
    # normalizing word vectors
    if nwords:
        feature_vector = np.divide(feature_vector, nwords) 
        # Output is an array wherein we have one vector corresponding to each corpus
    return feature_vector

# %%
def averaged_word_vectorizer(corpus, model, num_features):
    # Unique set of words inside the corpus
    vocabulary = set(model.wv.index2word)
    # Reading word vectors for each sentence and each word of the sentence
    features = [average_word_vectors(tokenized_sentence, model, vocabulary, num_features)
                    for tokenized_sentence in corpus]
    return np.array(features)

# %%
#      """ Reading excel file containing text to be processed and classified
#     It will be compatible as follows:
#     Args:
#         path (str): path to file
#         sheet (str: sheet name
#         columns (list): column names containing text to be processed

#     Returns:
#         list of feedbacks, where one feedback can contain multiple sentences

#     Example:
#         feedback_list = get_feedback_text('path/to/file.xlsx', 'Sheet Name', ['col1', 'col2'])
#     """
def read_file(path):
    return pd.read_excel(path)

# %%
def preprocess(df, l_c):
    # Consider two columns of feedbacks and topics corresponding to eeach feedback
    data = pd.DataFrame(columns=['text', 'topic'])
    for c in l_c:
        for index, row in df.iterrows():
            text = str(row[c])
            if((text!=' ')and(text!='nan')):
                i = len(data)
                # replacing all special char with space
                text = re.sub('[^a-zA-Z0-9\n]', ' ', text)
                # replacing multiple spaces with single space
                text = re.sub('\s+', ' ', text)
                # bring whole text to same lower-case scale.
                data.at[i, 'text'] = text.lower()
                data.at[i, 'topic'] = c
    data.text.dropna(inplace = True)
    data = data.replace({'topic':{l_c[0]: 't0', l_c[1]: 't1', l_c[2]: 't2', l_c[3]: 't3'}})
    return data

# %%
# Extract tokens from document
def tokenized_text(data):
    wpt = nltk.WordPunctTokenizer()
    tokenized_corpus = [wpt.tokenize(document) for document in data.text]
    return tokenized_corpus

# %%
# K-means clustering model 
def fit_model(X, true_k):
    # true_k is equal to number of clusters
    model = KMeans(n_clusters=true_k, init='k-means++', max_iter=200, n_init=1, random_state=1 )
    model.fit(X)
    data.loc[:,'labels'] = model.labels_
    return model

# %%
# Finding top topics in each cluster
def terms_per_cluster(trained, terms):
    print("Top terms per cluster:")
    order_centroids = trained.cluster_centers_.argsort()[:, ::-1]
    for i in range(true_k):
        print("Cluster %d:" % i),
        for ind in order_centroids[i, :15]:
            print(' %s' % terms[ind]),
        print('\n')

# %%
# Comparing results
def check_result(res, clusters):
    for k in range(clusters):
        for i in range(clusters):
            topic = 't' + str(i)
            acc = len(res[(res.labels == k) & (res.topic == topic)])/len(res[res.labels == k])
            print(topic + ' and ' + str(k) + ' : ' + str(acc))

# %%
def test_sent(test_text, trained_model, dicc, word2vec, feature_size):
    test_text = str(test_text)
    if((test_text!=' ')and(test_text!='nan')):
        # replacing all special char with space
        test_text = re.sub('[^a-zA-Z]', ' ', test_text)
        # replacing multiple spaces with single space
        test_text = re.sub('\s+', ' ', test_text)
        # bring whole text to same lower-case scale.
        test_text = test_text.lower()
        wpt = nltk.WordPunctTokenizer()
        sample = []
        for word in test_text.split():
            try:
                sample.append(word)
            except:
                pass
        sample = np.reshape(sample, (-1, len(sample)))
        sample = pd.DataFrame(averaged_word_vectorizer(corpus = sample, model = word2vec,
                                                       num_features = feature_size))
        sent = trained_model.predict(sample)
        result_topic = dicc[sent[0]]
        return result_topic
    else:
        return 'unkown'

# %%
path = 'Sample_1.xlsm'
l_col = [ 'you have any comments about 1 - character, please provide them here.',
      'you have any comments about 2 - centres, please provide them here.',
      'you have any comments about 3 - around, please provide them here.',
      'you have any comments about 4 - thing green, please provide them here.' 
      ]
true_k = 4

# %%
df = read_file(path)
data = preprocess(df, l_col)

# %%
data
# Out:
#                                                   text topic
# 0    block that bounders and st where 3 storeys are...    t0
# 1    rapid development of with large apartment buil...    t0
# 2    i think large apartment developments should be...    t0
# 3    i believe that allowing 5 storey unit developm...    t0
# 4    our logic is that prehouses with gardens is th...    t0
# ..                                                 ...   ...
# 838  to need to be the greenspace not more building...    t3
# 839          you not have development near or cb park     t3
# 840  trees need better care as many die as not wate...    t3
# 841  the number of young families and couples movin...    t3
# 842  that and prioritise actions contained within t...    t3
#
# [843 rows x 2 columns]

# %%
tokenized_corpus = tokenized_text(data)
tokenized_corpus
# Out:
# [['block',
#   'that',
#   'bounders',
#   'and',
#   'st',
#   'where',
#   '3',
#   'storeys',
#   'are',
#   'proposed',
#   'should',
#   'be',
#   'rezoned',
#   '5',
#   'storey',
#   'density',
#   'will',
#   'be',
#   'no',
#   'financial',
#   'incentive',
#   'for',
#   'developers',
#   'to',
#   'buy',
#   'out',
#   'those',
#   'owners',
#   'of',
#   'the',
#   'ugly',
#   'six',
#   'packs',
#   'to',
#   'move',
#   'on',
#   'to',
#   'redevelop',
#   'into',
#   '3',
#   'storeys',
#   'blocks',
#   'already',
#   'recently',
#   'redeveloped',
#   'will',
#   'not',
#   'change',
#   '20',
#   'years',
#   'from',
#   'now',
#   'nothing',
#   'will',
#   'change',
#   'unless',
#   '5',
#   'storey',
#   'medium',
#   'density',
#   'is',
#   'allowed',
#   'in',
#   'this',
#   'block'],
#  ['rapid',
#   'development',
#   'of',
#   'with',
#   'large',
#   'apartment',
#   'buildings',
#   'and',
#   'infills',
#   'is',
#   'very',
#   'poor',
#   'planning',
#   'and',
#   'has',
#   'dramatically',
#   'changed',
#   'the',
#   'suburb',
#   'and',
#   'its',
#   'character',
#   'a',
#   'lot',
#   'of',
#   'it',
#   'is',
#   'ugly',
#   'in',
#   'design',
#   'and',
#   'does',
#   'nothing',
#   'for',
#   'the',
#   'existing',
#   'residents',
#   'other',
#   'than',
#   'add',
#   'more',
#   'traffic',
#   'and',
#   'traffic',
#   'lights',
#   'needs',
#   'to',
#   'be',
#   'a',
#   'population',
#   'cap',
#   'on',
#   'the',
#   'suburb',
#   'rather',
#   'than',
#   'just',
#   'piling',
#   'in',
#   'more',
#   'people',
#   'every',
#   'year',
#   'are',
#   'yet',
#   'to',
#   'see',
#   'all',
#   'the',
#   'future',
#   'problems',
#   'from',
#   'the',
#   'approval',
#   'and',
#   'recent',
#   'construction',
#   'of',
#   'these',
#   'developments'],
#  ['i',
#   'think',
#   'large',
#   'apartment',
#   'developments',
#   'should',
#   'be',
#   'built',
#   'along',
#   'major',
#   'road',
#   'e',
#   'g',
#   'street',
#   'street',
#   'etc',
#   'i',
#   'do',
#   'not',
#   'agree',
#   'with',
#   'building',
#   'them',
#   'along',
#   'areas',
#   'with',
#   'large',
#   'parks',
#   'as',
#   'the',
#   'people',
#   'that',
#   'live',
#   'here',
#   'enjoy',
#   'the',
#   'being',
#   'able',
#   'to',
#   'look',
#   'out',
#   'their',
#   'windows',
#   'and',
#   'see',
#   'the',
#   'park',
#   'this',
#   'is',
#   'why',
#   'they',
#   'live',
#   'here'],
#  ['i',
#   'believe',
#   'that',
#   'allowing',
#   '5',
#   'storey',
#   'unit',
#   'development',
#   'in',
#   'is',
#   'absolutely',
#   'wrong',
#   'and',
#   'will',
#   'cause',
#   'major',
#   'concerns',
#   'for',
#   'other',
#   'residents',
#   'in',
#   'neighbouring',
#   'streets',
#   'levels',
#   'are',
#   'already',
#   'high',
#   'in',
#   'the',
#   'area',
#   'and',
#   'parking',
#   'problems',
#   'are',
#   'a',
#   'daily',
#   'occurrence',
#   'this',
#   'is',
#   'allowed',
#   'the',
#   'current',
#   'families',
#   'living',
#   'in',
#   'the',
#   'area',
#   'will',
#   'have',
#   'their',
#   'lifestyle',
#   'severely',
#   'impacted',
#   'and',
#   'children',
#   'will',
#   'be',
#   'at',
#   'risk',
#   'due',
#   'to',
#   'the',
#   'additional',
#   'road',
#   'traffic',
#   'and',
#   'parking',
#   'issues',
#   'i',
#   'disagree',
#   'and',
#   'object',
#   'to',
#   'this',
#   'proposal',
#   'very',
#   'strongly',
#   'and',
#   'consider',
#   '5',
#   'level',
#   'development',
#   'should',
#   'not',
#   'be',
#   'within',
#   'the',
#   'current',
#   'residential',
#   'area',
#   'and',
#   'residential',
#   'streets',
#   'and',
#   'should',
#   'be',
#   'restricted',
#   'to',
#   'main',
#   'roads',
#   'and',
#   'thoroughfares'],
#  ['our',
#   'logic',
#   'is',
#   'that',
#   'prehouses',
#   'with',
#   'gardens',
#   'is',
#   'the',
#   'neighbourhood',
#   'character',
#   'of',
#   'our',
#   'area',
#   'then',
#   'it',
#   'follows',
#   'that',
#   'the',
#   'character',
#   'is',
#   'reduced',
#   'every',
#   'time',
#   'a',
#   'single',
#   'prehouse',
#   'is',
#   'either',
#   'removed',
#   'or',
#   'built',
#   'around',
#   'with',
#   'backyard',
#   'apartments',
#   'heavy',
#   'demolition',
#   'activity',
#   'in',
#   'our',
#   'area',
#   'has',
#   'meant',
#   'that',
#   'very',
#   'few',
#   'streets',
#   'remain',
#   'intact',
#   'so',
#   'i',
#   'strongly',
#   'disagree',
#   'with',
#   'removing',
#   'the',
#   'building',
#   'character',
#   'overlay',
#   'from',
#   'fragmented',
#   'streetscapes',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'preserve',
#   'a',
#   'neighbourhood',
#   'character',
#   'then',
#   'those',
#   'fragmented',
#   'streets',
#   'need',
#   'to',
#   'have',
#   'their',
#   'remaining',
#   'character',
#   'houses',
#   'present',
#   'it',
#   's',
#   'also',
#   'very',
#   'sad',
#   'to',
#   'see',
#   'that',
#   'some',
#   'of',
#   'the',
#   'proposed',
#   'blocks',
#   'of',
#   'new',
#   'character',
#   'housing',
#   'overlay',
#   'e',
#   'g',
#   'and',
#   'greenslopes',
#   'will',
#   'actually',
#   'be',
#   'protecting',
#   'what',
#   'is',
#   'currently',
#   'demolished',
#   'lots',
#   'a',
#   'glimpse',
#   'of',
#   'the',
#   'draft',
#   'plan',
#   'seems',
#   'to',
#   'have',
#   'prompted',
#   'swift',
#   'demolition',
#   'of',
#   'character',
#   'houses',
#   'ahead',
#   'of',
#   'the',
#   'zoning',
#   'taking',
#   'effect',
#   'is',
#   'a',
#   'lot',
#   'more',
#   'of',
#   'our',
#   'area',
#   'that',
#   'should',
#   'be',
#   'under',
#   'character',
#   'residential',
#   'zoning',
#   'before',
#   'we',
#   'are',
#   'mostly',
#   'new',
#   'developments',
#   'and',
#   'i',
#   'm',
#   'disappointed',
#   'to',
#   'see',
#   'so',
#   'much',
#   'removed',
#   'from',
#   'coorparoo',
#   'with',
#   'so',
#   'little',
#   'added',
#   'to',
#   'greenslopes',
#   'i',
#   'hope',
#   'that',
#   'changing',
#   'the',
#   'zoning',
#   'to',
#   'allow',
#   'apartment',
#   'blocks',
#   'on',
#   'the',
#   'main',
#   'roads',
#   'and',
#   'along',
#   'parks',
#   'will',
#   'decrease',
#   'the',
#   'number',
#   'of',
#   'backyard',
#   'apartments',
#   'with',
#   'the',
#   'token',
#   'character',
#   'house',
#   'remaining',
#   'out',
#   'the',
#   'front',
#   'i',
#   'believe',
#   'it',
#   's',
#   'an',
#   'inefficient',
#   'strategy',
#   'to',
#   'generate',
#   'profits',
#   'but',
#   'contributes',
#   'to',
#   'urban',
#   'sprawl'],
#  ['survey',
#   'questions',
#   'use',
#   'too',
#   'much',
#   'technical',
#   'language',
#   'in',
#   'relation',
#   'to',
#   'development',
#   'and',
#   'so',
#   'most',
#   'people',
#   'are',
#   'not',
#   'able',
#   'to',
#   'understand',
#   'what',
#   'they',
#   'mean',
#   'is',
#   'this',
#   'meant',
#   'to',
#   'collect',
#   'informed',
#   'opinions',
#   'if',
#   'the',
#   'majority',
#   'of',
#   'people',
#   'don',
#   't',
#   'know',
#   'what',
#   'you',
#   're',
#   'referring',
#   'to'],
#  ['i',
#   'think',
#   'some',
#   'small',
#   'scale',
#   'residential',
#   'and',
#   'food',
#   'and',
#   'beverage',
#   'outlets',
#   'near',
#   'bus',
#   'station',
#   'would',
#   'be',
#   'beneficial',
#   'the',
#   'connection',
#   'between',
#   'the',
#   'east',
#   'and',
#   'west',
#   'sides',
#   'of',
#   'are',
#   'poor',
#   'and',
#   'access',
#   'to',
#   'shops',
#   'on',
#   'the',
#   'west',
#   'side',
#   'is',
#   'low',
#   'while',
#   'access',
#   'to',
#   'bikeways',
#   'on',
#   'the',
#   'east',
#   'side',
#   'is',
#   'poor',
#   'addressing',
#   'these',
#   'issues',
#   'and',
#   'possibly',
#   'redeveloping',
#   'the',
#   'area',
#   'around',
#   'bowls',
#   'club',
#   'with',
#   'low',
#   'medium',
#   'max',
#   '3',
#   'stories',
#   'residential',
#   'with',
#   'restaurants',
#   'and',
#   'cafes',
#   'would',
#   'liven',
#   'up',
#   'the',
#   'area',
#   'and',
#   'create',
#   'a',
#   'real',
#   'hub',
#   'building',
#   'heights',
#   'along',
#   'around',
#   'the',
#   'iga',
#   'also',
#   'seems',
#   'like',
#   'a',
#   'reasonable',
#   'idea',
#   'considering',
#   'there',
#   'is',
#   'little',
#   'street',
#   'appeal',
#   'in',
#   'that',
#   'area',
#   'anyway'],
#  ['homes',
#   'will',
#   'completely',
#   'disappear',
#   'if',
#   'they',
#   'are',
#   'not',
#   'protected',
#   'can',
#   't',
#   'developers',
#   'be',
#   'made',
#   'to',
#   'build',
#   'their',
#   'townhouses',
#   'in',
#   'character',
#   'with',
#   'the',
#   'street',
#   'they',
#   'are',
#   'building',
#   'them',
#   'in',
#   'e',
#   'g',
#   'no',
#   'flat',
#   'roofs',
#   'and',
#   'have',
#   'to',
#   'supply',
#   'parking',
#   'for',
#   '2',
#   'cars',
#   'rather',
#   'than',
#   'clogging',
#   'up',
#   'the',
#   'street',
#   'townhouses',
#   'that',
#   'i',
#   'know',
#   'use',
#   'their',
#   'garage',
#   'as',
#   'storage',
#   'and',
#   'park',
#   'on',
#   'the',
#   'street'],
#  ['i',
#   'believe',
#   'the',
#   'strategy',
#   'doesn',
#   't',
#   'adequately',
#   'protect',
#   'a',
#   'number',
#   'of',
#   'beautiful',
#   'streetscapes',
#   'around',
#   'greenslopes',
#   'i',
#   'also',
#   'believe',
#   'the',
#   'park',
#   'areas',
#   'would',
#   'have',
#   'reduced',
#   'amenity',
#   'with',
#   'unit',
#   'blocks',
#   'lining',
#   'them',
#   'i',
#   'believe',
#   'development',
#   'should',
#   'stay',
#   'along',
#   'logan',
#   'rd',
#   'with',
#   'perhaps',
#   'townhouses',
#   'or',
#   'maximum',
#   '2',
#   'story',
#   'apartment',
#   'blocks',
#   'near',
#   'the',
#   'hospital',
#   'for',
#   'accommodation'],
#  ['i',
#   'believe',
#   'the',
#   'strategy',
#   'doesn',
#   't',
#   'adequately',
#   'protect',
#   'a',
#   'number',
#   'of',
#   'beautiful',
#   'streetscapes',
#   'around',
#   'greenslopes',
#   'i',
#   'also',
#   'believe',
#   'the',
#   'park',
#   'areas',
#   'would',
#   'have',
#   'reduced',
#   'amenity',
#   'with',
#   'unit',
#   'blocks',
#   'lining',
#   'them',
#   'i',
#   'believe',
#   'development',
#   'should',
#   'stay',
#   'along',
#   'logan',
#   'rd',
#   'with',
#   'perhaps',
#   'townhouses',
#   'or',
#   'maximum',
#   '2',
#   'story',
#   'apartment',
#   'blocks',
#   'near',
#   'the',
#   'hospital',
#   'for',
#   'accommodation'],
#  ['seems',
#   'increased',
#   'density',
#   'up',
#   'to',
#   '6',
#   'storeys',
#   'in',
#   'some',
#   'instances',
#   'has',
#   'occurred',
#   'to',
#   'offset',
#   'the',
#   'increase',
#   'in',
#   'building',
#   'and',
#   'subsequent',
#   'reduced',
#   'density',
#   'increased',
#   'density',
#   'may',
#   'be',
#   'appropriate',
#   'around',
#   'the',
#   'hospital',
#   'shopping',
#   'centres',
#   'and',
#   'transport',
#   'corridors',
#   'it',
#   'is',
#   'definitely',
#   'not',
#   'appropriate',
#   'adjacent',
#   'to',
#   'park',
#   'and',
#   'cb',
#   'park',
#   'this',
#   'be',
#   'allowed',
#   'to',
#   'occur',
#   'the',
#   'character',
#   'of',
#   'the',
#   'parks',
#   'will',
#   'forever',
#   'be',
#   'changed',
#   'from',
#   'that',
#   'of',
#   'a',
#   'peaceful',
#   'open',
#   'sanctuary',
#   'to',
#   'a',
#   'closed',
#   'in',
#   'and',
#   'highly',
#   'urbanised',
#   'environment',
#   'which',
#   'is',
#   'overshadowed',
#   'and',
#   'overlooked',
#   'by',
#   'unnatural',
#   'hard',
#   'structures',
#   'which',
#   'no',
#   'amount',
#   'of',
#   'articulation',
#   'or',
#   'design',
#   'will',
#   'ever',
#   'change',
#   'space',
#   'needs',
#   'to',
#   'remain',
#   'exactly',
#   'that',
#   'open',
#   'space',
#   'sale',
#   'prices',
#   'may',
#   'be',
#   'desirable',
#   'for',
#   'developers',
#   'to',
#   'build',
#   'adjacent',
#   'to',
#   'the',
#   'park',
#   'and',
#   'nice',
#   'for',
#   'buyers',
#   'to',
#   'look',
#   'out',
#   'at',
#   'but',
#   'the',
#   'high',
#   'development',
#   'surrounding',
#   'the',
#   'park',
#   'will',
#   'greatly',
#   'detract',
#   'from',
#   'the',
#   'amenity',
#   'of',
#   'the',
#   'park',
#   'and',
#   'negatively',
#   'impact',
#   'on',
#   'the',
#   'use',
#   'and',
#   'enjoyment',
#   'of',
#   'the',
#   'park',
#   'for',
#   'the',
#   'many',
#   'many',
#   'park',
#   'visitors',
#   'which',
#   'greatly',
#   'outnumber',
#   'the',
#   'proposed',
#   'number',
#   'of',
#   'future',
#   'unit',
#   'dwellers',
#   'benefit',
#   'of',
#   'increased',
#   'development',
#   'adjacent',
#   'to',
#   'open',
#   'space',
#   'parks',
#   'does',
#   'not',
#   'equal',
#   'the',
#   'cost',
#   'of',
#   'loss',
#   'of',
#   'amenity',
#   'to',
#   'the',
#   'community',
#   'idea',
#   'of',
#   'increased',
#   'surveillance',
#   'is',
#   'rubbish',
#   'given',
#   'the',
#   'current',
#   'high',
#   'number',
#   'of',
#   'park',
#   'visitors',
#   'and',
#   'club',
#   'uses',
#   'which',
#   'will',
#   'only',
#   'increase',
#   'with',
#   'the',
#   'other',
#   'idea',
#   'of',
#   'improved',
#   'community',
#   'use',
#   'i',
#   'frequent',
#   'park',
#   'nearly',
#   'every',
#   'day',
#   'of',
#   'the',
#   'week',
#   'during',
#   'different',
#   'times',
#   'day',
#   'and',
#   'night',
#   'and',
#   'have',
#   'never',
#   'felt',
#   'unsafe',
#   'cafes',
#   'located',
#   'in',
#   'single',
#   'level',
#   'nondescript',
#   'buildings',
#   'would',
#   'serve',
#   'better',
#   'to',
#   'activate',
#   'the',
#   'parks',
#   'idea',
#   'of',
#   'increased',
#   'development',
#   'adjacent',
#   'to',
#   'parks',
#   'happened',
#   'at',
#   'and',
#   'it',
#   'has',
#   'ruined',
#   'the',
#   'previously',
#   'green',
#   'landscape',
#   'outlook',
#   'from',
#   'the',
#   'park',
#   'is',
#   'forever',
#   'blighted',
#   'with',
#   'the',
#   'sight',
#   'of',
#   'four',
#   'storey',
#   'urban',
#   'structures',
#   'do',
#   'not',
#   'let',
#   'this',
#   'happen',
#   'to',
#   'the',
#   'wonderful',
#   'city',
#   'parks',
#   'of',
#   'estate',
#   'and',
#   'cb',
#   'park',
#   'views',
#   'of',
#   'green',
#   'space',
#   'bordered',
#   'by',
#   'open',
#   'blue',
#   'sky',
#   'is',
#   'rare',
#   'and',
#   'should',
#   'be',
#   'cherished',
#   'just',
#   'as',
#   'much',
#   'as',
#   'traditional',
#   'building',
#   'character',
#   'density',
#   'especially',
#   '6',
#   'storey',
#   'medium',
#   'is',
#   'more',
#   'appropriate',
#   'around',
#   'public',
#   'transport',
#   'corridors',
#   'and',
#   'shopping',
#   'facilities',
#   'i',
#   'e',
#   'around',
#   'shopping',
#   'centres',
#   'along',
#   'or',
#   'area',
#   'south',
#   'of',
#   'and',
#   'between',
#   'and',
#   'busway',
#   'station',
#   'or',
#   'even',
#   'bordering',
#   'near',
#   'stones',
#   'corner'],
#  ['halt',
#   'migration',
#   'has',
#   'become',
#   'overpopulated',
#   'record',
#   'unemployment',
#   'and',
#   'high',
#   'rental',
#   'prices'],
#  ['because',
#   'an',
#   'area',
#   'has',
#   'been',
#   'fragmented',
#   'by',
#   'development',
#   'doesn',
#   't',
#   'mean',
#   'the',
#   'existing',
#   'character',
#   'housing',
#   'isn',
#   't',
#   'important',
#   'i',
#   'think',
#   'you',
#   'need',
#   'to',
#   'protect',
#   'houses',
#   'around',
#   'the',
#   'area',
#   'knowsley',
#   'streets',
#   'in',
#   'instead',
#   'of',
#   'marking',
#   'this',
#   'area',
#   'for',
#   'high',
#   'development',
#   'a',
#   'mixture',
#   'of',
#   'character',
#   'housing',
#   'containing',
#   'families',
#   'and',
#   'retired',
#   'people',
#   'as',
#   'well',
#   'as',
#   'units',
#   'containing',
#   'students',
#   'is',
#   'very',
#   'important',
#   'also',
#   'why',
#   'is',
#   'a',
#   '12',
#   'storey',
#   '99',
#   'unit',
#   'block',
#   'being',
#   'planned',
#   'for',
#   'street',
#   'is',
#   'absolutely',
#   'preposterous',
#   'and',
#   'completely',
#   'out',
#   'of',
#   'keeping',
#   'with',
#   'the',
#   'suburb',
#   's',
#   'look',
#   'and',
#   'feel',
#   'are',
#   'already',
#   'onstreet',
#   'parking',
#   'problems',
#   'in',
#   'this',
#   'area',
#   'due',
#   'to',
#   'too',
#   'many',
#   'units',
#   'with',
#   'not',
#   'enough',
#   'capacity',
#   'in',
#   'their',
#   'garages',
#   'for',
#   'the',
#   'tenants',
#   'is',
#   'making',
#   'this',
#   'problem',
#   'worse'],
#  ['decides', 'to', 'lodge', 'a', 'challenge'],
#  ['it',
#   'alone',
#   'there',
#   'are',
#   'too',
#   'many',
#   'sights',
#   'going',
#   'higher',
#   'and',
#   'blocking',
#   'the',
#   'views',
#   'we',
#   'have',
#   'always',
#   'had',
#   'many',
#   'buildings',
#   'would',
#   'rather',
#   'money',
#   'be',
#   'spent',
#   'on',
#   'fixing',
#   'roads',
#   'in',
#   'area',
#   'the',
#   'parklands',
#   'alone'],
#  ['i',
#   'am',
#   'long',
#   'term',
#   'resident',
#   'of',
#   'this',
#   'area',
#   'and',
#   'i',
#   'am',
#   'generally',
#   'happy',
#   'to',
#   'see',
#   'that',
#   'acc',
#   'are',
#   'allowing',
#   'expansion',
#   'and',
#   'development',
#   'in',
#   'and',
#   'around',
#   'the',
#   'to',
#   'further',
#   'enhance',
#   'it',
#   'as',
#   'a',
#   'hub',
#   'of',
#   'activity',
#   'and',
#   'then',
#   'link',
#   'it',
#   'better',
#   'with',
#   'the',
#   'hub',
#   'at',
#   'rd'],
#  ['need',
#   'to',
#   'protect',
#   'the',
#   'heritage',
#   'and',
#   'character',
#   'of',
#   'homes',
#   'that',
#   'gives',
#   'queensland',
#   'it',
#   's',
#   'unique',
#   'style',
#   'on',
#   'the',
#   'map',
#   'housing',
#   'should',
#   'remain',
#   'to',
#   'blend',
#   'in',
#   'with',
#   'the',
#   'existing',
#   'beautiful',
#   'character',
#   'of',
#   'homes',
#   'restrictions',
#   'of',
#   'medium',
#   'residential',
#   'should',
#   'be',
#   'limited',
#   'so',
#   'that',
#   'the',
#   'existing',
#   'homes',
#   'don',
#   't',
#   'loose',
#   'their',
#   'backyard',
#   'feel',
#   'that',
#   'most',
#   'of',
#   'us',
#   'paid',
#   'good',
#   'money',
#   'for'],
#  ['a',
#   'resident',
#   'of',
#   'west',
#   'i',
#   'strongly',
#   'disagree',
#   'with',
#   'the',
#   'proposed',
#   're',
#   'zoning',
#   'of',
#   'all',
#   'land',
#   'in',
#   'this',
#   'street',
#   'existing',
#   'plan',
#   'already',
#   'does',
#   'not',
#   'allow',
#   'for',
#   'a',
#   'prehouse',
#   'to',
#   'be',
#   'demolished',
#   'furthermore',
#   'any',
#   'post',
#   'home',
#   'if',
#   'demolished',
#   'redeveloped',
#   'needs',
#   'to',
#   'meet',
#   'specific',
#   'character',
#   'conditions',
#   'to',
#   'uphold',
#   'the',
#   'streetscape',
#   'as',
#   'it',
#   'is',
#   'protections',
#   'are',
#   'already',
#   'in',
#   'place',
#   'regards',
#   'to',
#   'st',
#   'there',
#   'is',
#   'now',
#   'an',
#   'argument',
#   'to',
#   'change',
#   'the',
#   'zoning',
#   'of',
#   'the',
#   'entire',
#   'street',
#   'to',
#   'protect',
#   'the',
#   'prestreetscape',
#   'when',
#   'in',
#   'fact',
#   'there',
#   'are',
#   'several',
#   'post',
#   'houses',
#   'approx',
#   'half',
#   'the',
#   'street',
#   'a',
#   'huge',
#   'block',
#   'of',
#   'units',
#   'already',
#   'at',
#   'the',
#   'top',
#   'of',
#   'the',
#   'street',
#   'and',
#   'recent',
#   'approval',
#   'granted',
#   'for',
#   'units',
#   'at',
#   'no',
#   '28',
#   'a',
#   'modern',
#   'home',
#   'has',
#   'been',
#   'constructed',
#   'at',
#   'no24',
#   'there',
#   'are',
#   'approx',
#   '6',
#   'homes',
#   'left',
#   'on',
#   'the',
#   'street',
#   'that',
#   'are',
#   'preand',
#   'these',
#   'are',
#   'already',
#   'protected',
#   'from',
#   'demolition',
#   'and',
#   'that',
#   'will',
#   'not',
#   'change',
#   'other',
#   'properties',
#   'that',
#   'have',
#   'houses',
#   'built',
#   'post',
#   'should',
#   'remain',
#   'in',
#   'the',
#   'current',
#   'zoning',
#   'as',
#   'this',
#   'was',
#   'a',
#   'factor',
#   'for',
#   'home',
#   'owners',
#   'when',
#   'purchasing',
#   'their',
#   'property',
#   'change',
#   'the',
#   'zoning',
#   'would',
#   'result',
#   'in',
#   'a',
#   'de',
#   'valuing',
#   'of',
#   'the',
#   'property',
#   'for',
#   'those',
#   'owners',
#   'who',
#   'purchased',
#   'with',
#   'future',
#   'development',
#   'in',
#   'mind',
#   'is',
#   'also',
#   'noted',
#   'in',
#   'the',
#   'new',
#   'strategy',
#   'that',
#   'development',
#   'and',
#   'an',
#   'increase',
#   'in',
#   'housing',
#   'close',
#   'to',
#   'and',
#   'public',
#   'transport',
#   'is',
#   'highly',
#   'valued',
#   'is',
#   'located',
#   'directly',
#   'adjacent',
#   'to',
#   'with',
#   'an',
#   'excellent',
#   'transport',
#   'option',
#   'that',
#   'being',
#   '2',
#   'bus',
#   'stops',
#   'within',
#   '100',
#   'metres',
#   'our',
#   'opinion',
#   'the',
#   'location',
#   'of',
#   'is',
#   'ideal',
#   'for',
#   'carefully',
#   'considered',
#   'development',
#   'for',
#   'the',
#   'future',
#   'of',
#   'and',
#   'its',
#   'expected',
#   'population',
#   'growth',
#   'zoning',
#   'that',
#   'is',
#   'currently',
#   'in',
#   'place',
#   'clearly',
#   'supports',
#   'this',
#   'opinion',
#   'and',
#   'is',
#   'more',
#   'than',
#   'suitable',
#   'to',
#   'protect',
#   'from',
#   'over',
#   'development',
#   'allowing',
#   'only',
#   'post',
#   'homes',
#   'to',
#   'be',
#   'demolished',
#   'are',
#   'also',
#   'strict',
#   'conditions',
#   'in',
#   'regards',
#   'to',
#   'preserving',
#   'the',
#   'character',
#   'of',
#   'the',
#   'streetscapes',
#   'eg',
#   'ensuring',
#   'the',
#   'fascade',
#   'of',
#   'the',
#   'development',
#   'materials',
#   'used',
#   'are',
#   'in',
#   'keeping',
#   'with',
#   'the',
#   'surrounding',
#   'homes',
#   'a',
#   'home',
#   'owner',
#   'on',
#   'i',
#   'believe',
#   'my',
#   'lands',
#   'zoning',
#   'should',
#   'not',
#   'be',
#   'changed',
#   'because',
#   'another',
#   'resident',
#   'of',
#   'doesn',
#   't',
#   'want',
#   'any',
#   'development',
#   'in',
#   'their',
#   'street',
#   'including',
#   'one',
#   'such',
#   'resident',
#   'who',
#   'sits',
#   'on',
#   'the',
#   'committee'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'see',
#   'some',
#   'discouragement',
#   'to',
#   'the',
#   'dominating',
#   'block',
#   'split',
#   'monolith',
#   'style',
#   'dwellings',
#   'that',
#   'are',
#   'now',
#   'tending',
#   'to',
#   'fill',
#   'the',
#   'small',
#   'blocks',
#   'and',
#   'ruin',
#   'the',
#   'feel',
#   'and',
#   'aesthetics',
#   'in',
#   'previously',
#   'zoned',
#   'residential',
#   'a',
#   'areas',
#   'of',
#   'coorparoo',
#   'hill',
#   'architecture',
#   'leaves',
#   'little',
#   'room',
#   'for',
#   'trees',
#   'open',
#   'space',
#   'and',
#   'street',
#   'parking',
#   'promoting',
#   'a',
#   'feeling',
#   'of',
#   'congestion',
#   'and',
#   'unhealthy',
#   'social',
#   'lifestyle',
#   'where',
#   'do',
#   'the',
#   'children',
#   'play',
#   'etc'],
#  ['bought',
#   'our',
#   'house',
#   'and',
#   'were',
#   'well',
#   'aware',
#   'of',
#   'the',
#   'zoning',
#   'have',
#   'lots',
#   'of',
#   'units',
#   'and',
#   'townhouses',
#   'around',
#   'us',
#   'who',
#   'object',
#   'to',
#   'units',
#   'and',
#   'townhouses',
#   'knew',
#   'when',
#   'buying',
#   'into',
#   'these',
#   'areas',
#   'the',
#   'zoning',
#   'now',
#   'do',
#   'people',
#   'who',
#   'are',
#   'the',
#   'minority',
#   'think',
#   'they',
#   'can',
#   'change',
#   'the',
#   'zoning',
#   'to',
#   'suit',
#   'themselves',
#   'invested',
#   'in',
#   'this',
#   'area',
#   'knowing',
#   'the',
#   'zoning',
#   'would',
#   'accommodate',
#   'to',
#   'allow',
#   'for',
#   'our',
#   'future',
#   'new',
#   'proposal',
#   'will',
#   'be',
#   'a',
#   'financial',
#   'set',
#   'back',
#   'not',
#   'only',
#   'for',
#   'ourselves',
#   'but',
#   'for',
#   'many',
#   'others',
#   'also',
#   'residents'],
#  ['storeys',
#   'along',
#   'road',
#   'near',
#   'holland',
#   'park',
#   'hotel',
#   'is',
#   'too',
#   'high',
#   'will',
#   'create',
#   'large',
#   'shaded',
#   'areas',
#   'on',
#   'both',
#   'sides',
#   'of',
#   'road',
#   'making',
#   'for',
#   'an',
#   'uninviting',
#   'and',
#   'intimidating',
#   'stretch',
#   'of',
#   'road',
#   'developments',
#   'to',
#   'achieve',
#   'the',
#   'height',
#   'will',
#   'be',
#   'out',
#   'of',
#   'character',
#   'for',
#   'the',
#   'area'],
#  ['of',
#   '5',
#   'or',
#   '6',
#   'storeys',
#   'along',
#   'road',
#   'near',
#   'would',
#   'create',
#   'a',
#   'tunnel',
#   'of',
#   'wind',
#   'and',
#   'shade',
#   'that',
#   'would',
#   'be',
#   'uninviting',
#   'and',
#   'intimidating',
#   'is',
#   'a',
#   'very',
#   'narrow',
#   'section',
#   'of',
#   'road',
#   'of',
#   'new',
#   'properties',
#   'to',
#   'this',
#   'height',
#   'boundary',
#   'would',
#   'not',
#   'be',
#   'in',
#   'character',
#   'with',
#   'park',
#   's',
#   'historic',
#   'value'],
#  ['in',
#   'large',
#   'flats',
#   'up',
#   'to',
#   '3',
#   '5',
#   'stories',
#   'will',
#   'erode',
#   'the',
#   'character',
#   'of',
#   'this',
#   'historic',
#   'neighbourhood',
#   'of',
#   'which',
#   'there',
#   'is',
#   'already',
#   'plentiful',
#   'suburban',
#   'housing'],
#  ['i',
#   'am',
#   'not',
#   'in',
#   'favour',
#   'of',
#   'reducing',
#   'character',
#   'protection',
#   'for',
#   'any',
#   'area',
#   'that',
#   'is',
#   'not',
#   'directly',
#   'on',
#   'a',
#   'transport',
#   'route'],
#  ['to',
#   'the',
#   'regulations',
#   'for',
#   'everyone',
#   'seem',
#   'to',
#   'be',
#   'inconsistent',
#   'with',
#   'approvals',
#   'for',
#   'renovations',
#   'and',
#   'building'],
#  ['draft',
#   'is',
#   'destroying',
#   'the',
#   'character',
#   'of',
#   'the',
#   'suburb',
#   'particularly',
#   'around',
#   'the',
#   'park',
#   'plan',
#   'and',
#   'the',
#   'flyer',
#   'seem',
#   'to',
#   'have',
#   'been',
#   'written',
#   'by',
#   'developers'],
#  ['oppose',
#   'development',
#   'adjacent',
#   'to',
#   'parks',
#   'and',
#   'open',
#   'space',
#   'acceptable',
#   'adjacent',
#   'to',
#   'roads',
#   'road',
#   'and',
#   'shopping',
#   'centres',
#   'gs',
#   'mall',
#   'depot',
#   'should',
#   'become',
#   'parkland',
#   'if',
#   'operations',
#   'ever',
#   'cease',
#   'densities',
#   'in',
#   'requires',
#   'increased',
#   'open',
#   'space',
#   'to',
#   'offset'],
#  ['introduction',
#   'of',
#   '5',
#   'storey',
#   'buildings',
#   'along',
#   'and',
#   '3',
#   'story',
#   'building',
#   'in',
#   'from',
#   'road',
#   'isn',
#   't',
#   'going',
#   'to',
#   'add',
#   'to',
#   'the',
#   'character',
#   'of',
#   'and',
#   'is',
#   'simply',
#   'going',
#   'to',
#   'close',
#   'in',
#   'all',
#   'the',
#   'residents'],
#  ['i',
#   'dont',
#   'think',
#   'any',
#   'greater',
#   'development',
#   'than',
#   'is',
#   'currently',
#   'allowed',
#   'lmr2',
#   'should',
#   'occur',
#   'next',
#   'to',
#   'parks'],
#  ['development',
#   '5',
#   'storeys',
#   'should',
#   'not',
#   'occur',
#   'near',
#   'larger',
#   'parks',
#   'q3',
#   'logan',
#   'rd',
#   'is',
#   'fine',
#   'also',
#   'increase',
#   'setbacks',
#   'to',
#   'larger',
#   'parks',
#   'q5',
#   'depot',
#   'should',
#   'be',
#   'made',
#   'park',
#   'q6'],
#  ['and',
#   'surrounding',
#   'streets',
#   'are',
#   'already',
#   'being',
#   'used',
#   'by',
#   'bus',
#   'commuters',
#   'to',
#   'park',
#   'their',
#   'cars',
#   'so',
#   'future',
#   'off',
#   'street',
#   'car',
#   'parking',
#   'in',
#   'this',
#   'area',
#   'would',
#   'be',
#   'good',
#   'to',
#   'accommodate',
#   'use',
#   'projecting',
#   'into',
#   '20',
#   'year',
#   'capacity',
#   'greening',
#   'of',
#   'this',
#   'streetscape',
#   'strip',
#   'would',
#   'be',
#   'good',
#   'too'],
#  ['not', 'allow', 'development', 'near', 'open', 'space'],
#  ['is',
#   'a',
#   'major',
#   'transport',
#   'corridor',
#   'in',
#   'contrast',
#   'to',
#   'that',
#   'is',
#   'a',
#   'quiet',
#   'residential',
#   'street',
#   'increased',
#   'residential',
#   'density',
#   'and',
#   'mixed',
#   'use',
#   'development',
#   'is',
#   'appropriate',
#   'along',
#   'it',
#   'is',
#   'not',
#   'appropriate',
#   'on',
#   'street'],
#  ['are',
#   'very',
#   'disappointed',
#   'that',
#   'the',
#   'properties',
#   'in',
#   'near',
#   'and',
#   'are',
#   'not',
#   'marked',
#   'on',
#   'the',
#   'map',
#   'as',
#   'listed',
#   'property',
#   'in',
#   'is',
#   'not',
#   'shown',
#   'as',
#   'listed',
#   'however',
#   'we',
#   'have',
#   'received',
#   'notification',
#   'from',
#   'the',
#   'council',
#   'previously',
#   'that',
#   'it',
#   'listed',
#   'as',
#   'a',
#   'dwelling',
#   'is',
#   'happening',
#   'is',
#   'not',
#   'acceptable'],
#  ['i',
#   'strongly',
#   'against',
#   'the',
#   'plan',
#   'of',
#   'building',
#   '5',
#   'storeys',
#   'units',
#   'on',
#   'denman',
#   'street',
#   'abound',
#   'the',
#   'hospital',
#   'has',
#   'already',
#   'full',
#   'of',
#   'units',
#   'and',
#   'townhouses',
#   'i',
#   'am',
#   'very',
#   'concerned',
#   'about',
#   'the',
#   'parking',
#   'problem',
#   'which',
#   'is',
#   'already',
#   'complained',
#   'by',
#   'patients',
#   'and',
#   'visitors',
#   'addition',
#   '5',
#   'storey',
#   'building',
#   'with',
#   'ruin',
#   'the',
#   'overall',
#   'look',
#   'of',
#   'this',
#   'beautiful',
#   'historic',
#   'community',
#   'but',
#   'not',
#   'least',
#   'i',
#   'can',
#   't',
#   'see',
#   'any',
#   'point',
#   'of',
#   'having',
#   'more',
#   'residential',
#   'buildings',
#   'around',
#   'the',
#   'hospital',
#   'because',
#   'the',
#   'hospital',
#   'will',
#   'not',
#   'grow',
#   'into',
#   'a',
#   'mega',
#   'hospital',
#   'like',
#   'mater',
#   'or',
#   'pa',
#   'hospital',
#   'due',
#   'to',
#   'its',
#   'limited',
#   'space'],
#  ['is',
#   'only',
#   'two',
#   'years',
#   'old',
#   'too',
#   'soon',
#   'to',
#   'be',
#   'making',
#   'significant',
#   'zoning',
#   'changes',
#   'have',
#   'already',
#   'made',
#   'investment',
#   'decisions',
#   'based',
#   'on',
#   'current',
#   'zoning'],
#  ['my',
#   'opinion',
#   'there',
#   'is',
#   'no',
#   'place',
#   'for',
#   'highrises',
#   'in',
#   'family',
#   'suburbs',
#   'not',
#   'on',
#   'a',
#   'main',
#   'road',
#   'doesn',
#   't',
#   'take',
#   'long',
#   'to',
#   'see',
#   'how',
#   'many',
#   'people',
#   'are',
#   'renovating',
#   'extending',
#   'their',
#   'homes',
#   'in',
#   'their',
#   'current',
#   'neighbourhoods',
#   'which',
#   'surely',
#   'is',
#   'a',
#   'reflection',
#   'of',
#   'people',
#   'wanting',
#   'to',
#   'remain',
#   'i',
#   'e',
#   'they',
#   'like',
#   'their',
#   'areas',
#   'as',
#   'they',
#   'are',
#   'don',
#   't',
#   'change',
#   'them',
#   'for',
#   'the',
#   'majority',
#   'its',
#   'not',
#   'the',
#   'current',
#   'homeowners',
#   'who',
#   'are',
#   'the',
#   'developers',
#   'they',
#   'are',
#   'merely',
#   'being',
#   'edged',
#   'pushed',
#   'out',
#   'by',
#   'people',
#   'who',
#   'are',
#   'external',
#   'to',
#   'the',
#   'community',
#   'and',
#   'unsympathetic',
#   'to',
#   'the',
#   'people',
#   'that',
#   'live',
#   'in',
#   'it'],
#  ['draft',
#   'proposal',
#   'suggests',
#   'development',
#   'up',
#   'to',
#   '6',
#   'storeys',
#   'in',
#   'some',
#   'location',
#   'and',
#   'yet',
#   'the',
#   'question',
#   'in',
#   'this',
#   'survey',
#   'refers',
#   'to',
#   'only',
#   'five',
#   'is',
#   'misleading',
#   'additionally',
#   'removal',
#   'of',
#   'protection',
#   'for',
#   'housing',
#   'in',
#   'areas',
#   'where',
#   'the',
#   'street',
#   'scape',
#   'has',
#   'already',
#   'been',
#   'lost',
#   'should',
#   'be',
#   'decided',
#   'on',
#   'a',
#   'case',
#   'by',
#   'case',
#   'basis',
#   'as',
#   'many',
#   'historic',
#   'houses',
#   'are',
#   'contained',
#   'in',
#   'these',
#   'streets',
#   'i',
#   'would',
#   'also',
#   'like',
#   'to',
#   'see',
#   'some',
#   'protection',
#   'on',
#   'post',
#   'homes',
#   'such',
#   'as',
#   'in',
#   'lamb',
#   's',
#   'where',
#   'there',
#   'are',
#   'large',
#   'blocks',
#   'of',
#   'land',
#   'with',
#   'beautiful',
#   's',
#   'architecture'],
#  ['property',
#   'in',
#   'on',
#   'is',
#   'already',
#   'affected',
#   'by',
#   'numbers',
#   'of',
#   'vehicles',
#   'and',
#   'trailers',
#   'parked',
#   'in',
#   'the',
#   'streets',
#   'many',
#   'of',
#   'which',
#   'are',
#   'quite',
#   'narrow',
#   'the',
#   'draft',
#   'plan',
#   'clearly',
#   'aims',
#   'to',
#   'allow',
#   'a',
#   'modest',
#   'increase',
#   'in',
#   'the',
#   'current',
#   'population',
#   'density',
#   'this',
#   'will',
#   'be',
#   'disastrous',
#   'unless',
#   'firm',
#   'rules',
#   'are',
#   'applied',
#   'on',
#   'use',
#   'of',
#   'public',
#   'streets',
#   'for',
#   'parking'],
#  ['to',
#   'walls',
#   'should',
#   'not',
#   'be',
#   'permitted',
#   'without',
#   'the',
#   'agreement',
#   'of',
#   'the',
#   'neighbour',
#   'and',
#   'a',
#   'formal',
#   'relaxation',
#   'granted',
#   'by',
#   'the',
#   'acc',
#   'the',
#   'past',
#   'the',
#   'acc',
#   'has',
#   'permitted',
#   'built',
#   'to',
#   'boundary',
#   'walls',
#   'in',
#   'low',
#   'and',
#   'has',
#   'ignored',
#   'the',
#   'objections',
#   'of',
#   'adjoining',
#   'property',
#   'owners',
#   'refer',
#   'to',
#   'my',
#   'objections',
#   'to',
#   'the',
#   'large',
#   'unit',
#   'block',
#   'constructed',
#   'at',
#   'annerley',
#   'i',
#   'was',
#   'the',
#   'owner',
#   'of',
#   'the',
#   'adjacent',
#   'block',
#   'at',
#   'and',
#   'my',
#   'valid',
#   'objections',
#   'about',
#   'the',
#   'effect',
#   'of',
#   'the',
#   'built',
#   'to',
#   'boundary',
#   'wall',
#   'on',
#   'my',
#   'property',
#   'boundary',
#   'were',
#   'entirely',
#   'ignored',
#   'by',
#   'the',
#   'acc',
#   'unit',
#   'block',
#   'was',
#   'unnecessarily',
#   'wide',
#   'simply',
#   'so',
#   'the',
#   'developer',
#   'could',
#   'construct',
#   'excessively',
#   'long',
#   'garage',
#   'spaces',
#   'and',
#   'maximise',
#   'their',
#   'commercial',
#   'gain',
#   'at',
#   'the',
#   'expense',
#   'of',
#   'the',
#   'amenity',
#   'of',
#   'my',
#   'property'],
#  ['reinstate',
#   'protections',
#   'for',
#   'the',
#   'south',
#   'side',
#   'of',
#   'street',
#   'hill',
#   'street',
#   'has',
#   'a',
#   'highly',
#   'intact',
#   'prebuilt',
#   'form',
#   'on',
#   'the',
#   'north',
#   'side',
#   'and',
#   'development',
#   'on',
#   'the',
#   'south',
#   'must',
#   'be',
#   'sympathetic',
#   'to',
#   'that',
#   'character',
#   'which',
#   'the',
#   'character',
#   'protection',
#   'assists',
#   'to',
#   'deliver'],
#  ['no',
#   'repeat',
#   'no',
#   'hi',
#   'rise',
#   '5',
#   'storey',
#   'development',
#   'along',
#   'denman',
#   'street',
#   'traffic',
#   'and',
#   'congestion',
#   'will',
#   'increase',
#   'i',
#   'am',
#   'sick',
#   'of',
#   'that',
#   'f',
#   'hospital',
#   'its',
#   'staff',
#   'and',
#   'visitors',
#   'associated',
#   'traffic',
#   'impeding',
#   'on',
#   'my',
#   'lifestyle',
#   'and',
#   'right',
#   'to',
#   'enjoy',
#   'my',
#   'property'],
#  ['character',
#   'housing',
#   'the',
#   'neighbourhood',
#   'is',
#   'lost',
#   'and',
#   'you',
#   'are',
#   'only',
#   'left',
#   'with',
#   'so',
#   'many',
#   'boxes',
#   'has',
#   'so',
#   'little',
#   'heritage',
#   'that',
#   'it',
#   'would',
#   'be',
#   'foolish',
#   'to',
#   'allow',
#   'even',
#   'more',
#   'to',
#   'be',
#   'lost',
#   'the',
#   'essence',
#   'of',
#   'our',
#   'suburbs',
#   'gives',
#   'everyone',
#   'something',
#   'nice',
#   'to',
#   'look',
#   'at',
#   'residents',
#   'and',
#   'visitors',
#   'alike'],
#  ['concept',
#   'of',
#   'easing',
#   'restrictions',
#   'on',
#   'character',
#   'homes',
#   'and',
#   'development',
#   'size',
#   'on',
#   'near',
#   'the',
#   'is',
#   'a',
#   'very',
#   'good',
#   'idea',
#   'which',
#   'i',
#   'wholeheartedly',
#   'support'],
#  ['character',
#   'is',
#   'currently',
#   'being',
#   'totally',
#   'destroyed',
#   'by',
#   'allowing',
#   'houses',
#   'on',
#   '800m2',
#   'to',
#   'be',
#   'moved',
#   'to',
#   'one',
#   'side',
#   'of',
#   'the',
#   'block',
#   'or',
#   'totally',
#   'removed',
#   'demolished',
#   'and',
#   '2',
#   'houses',
#   'built',
#   'on',
#   '400m2',
#   'each',
#   'new',
#   'houses',
#   'are',
#   'sometimes',
#   'poor',
#   'imitations',
#   'of',
#   'queenslanders',
#   'or',
#   'nothing',
#   'like',
#   'it'],
#  ['the',
#   'current',
#   'plan',
#   'as',
#   'is',
#   'more',
#   'development',
#   'near',
#   'shops',
#   'or',
#   'parks'],
#  ['proposal',
#   'of',
#   'medium',
#   'residential',
#   'zone',
#   'in',
#   'is',
#   'not',
#   'appropriate',
#   'is',
#   'a',
#   'suburban',
#   'side',
#   'street',
#   'not',
#   'a',
#   'main',
#   'road',
#   'already',
#   'has',
#   'low',
#   'medium',
#   'density',
#   'and',
#   'issues',
#   'with',
#   'traffic',
#   'and',
#   'noise',
#   'there',
#   'is',
#   'a',
#   'park',
#   'on',
#   'one',
#   'side',
#   'this',
#   'does',
#   'not',
#   'negate',
#   'the',
#   'impacts',
#   'these',
#   'buildings',
#   'will',
#   'existing',
#   'residents'],
#  ['to',
#   '5',
#   '6',
#   'storeys',
#   'along',
#   'road',
#   'and',
#   'other',
#   'parts',
#   'of',
#   'park',
#   'would',
#   'adversely',
#   'affect',
#   'the',
#   'community',
#   'feel',
#   'of',
#   'the',
#   'suburb',
#   'of',
#   'the',
#   'suburb',
#   'would',
#   'be',
#   'lost',
#   'and',
#   'dwarfed',
#   'by',
#   'these',
#   'buildings',
#   'new',
#   'building',
#   'on',
#   'the',
#   'corner',
#   'of',
#   'dwarfs',
#   'everything',
#   'around',
#   'it',
#   'i',
#   'have',
#   'recently',
#   'renovated',
#   'a',
#   'prewar',
#   'and',
#   'i',
#   'shudder',
#   'to',
#   'think',
#   'that',
#   '6',
#   'storeys',
#   'could',
#   'be',
#   'built',
#   '2',
#   'doors',
#   'up',
#   'from',
#   'me'],
#  ['i',
#   'think',
#   'you',
#   're',
#   'idea',
#   'is',
#   'a',
#   'terrible',
#   'idea',
#   'and',
#   'quite',
#   'frankly',
#   'i',
#   'think',
#   'the',
#   'persons',
#   'who',
#   'came',
#   'up',
#   'with',
#   'it',
#   'are',
#   'utter',
#   'morons',
#   'and',
#   'should',
#   'be',
#   'fired',
#   'i',
#   'love',
#   'this',
#   'area',
#   'and',
#   'its',
#   'great',
#   'character',
#   'as',
#   'it',
#   'is',
#   'and',
#   'i',
#   'always',
#   'will'],
#  ['i',
#   'do',
#   'not',
#   'agree',
#   'with',
#   'the',
#   'proposal',
#   'to',
#   'develop',
#   'to',
#   'the',
#   'height',
#   'of',
#   '5',
#   'storeys',
#   'i',
#   'think',
#   'this',
#   'will',
#   'have',
#   'a',
#   'negative',
#   'imapact',
#   'on',
#   'the',
#   'surrounding',
#   'area',
#   'i',
#   'believe',
#   'that',
#   'development',
#   'of',
#   'this',
#   'height',
#   'should',
#   'be',
#   'confined',
#   'to',
#   'major',
#   'roads',
#   'such',
#   'as',
#   'road'],
#  ['my',
#   'opinion',
#   'st',
#   'is',
#   'not',
#   'large',
#   'enough',
#   'to',
#   'support',
#   'increased',
#   'traffic',
#   'including',
#   'parking',
#   'needs',
#   'etc',
#   'associated',
#   'with',
#   'increased',
#   'residential',
#   'and',
#   'short',
#   'term',
#   'accommodation',
#   'developments',
#   'up',
#   'to',
#   '5',
#   'storeys',
#   'development',
#   'will',
#   'have',
#   'a',
#   'detrimental',
#   'effect',
#   'on',
#   'the',
#   'surrounding',
#   'neighbourhood'],
#  ['do',
#   'not',
#   'allow',
#   'any',
#   'further',
#   'increase',
#   'in',
#   'development',
#   'directly',
#   'adjacent',
#   'to',
#   'open',
#   'space'],
#  ['suburbs',
#   'are',
#   'at',
#   'risk',
#   'of',
#   'losing',
#   'their',
#   'identity',
#   'for',
#   'which',
#   'people',
#   'have',
#   'originally',
#   'moved',
#   'here',
#   'for',
#   'privacy',
#   'and',
#   'impact',
#   'to',
#   'existing',
#   'housing',
#   'must',
#   'be',
#   'respected',
#   'is',
#   'way',
#   'too',
#   'high',
#   'and',
#   'looks',
#   'ridiculous',
#   'besides',
#   'existing',
#   'housing'],
#  ['width',
#   'needs',
#   'to',
#   'be',
#   'considered',
#   'as',
#   'does',
#   'parking',
#   'in',
#   'the',
#   'streets',
#   'off',
#   'street',
#   'parking',
#   'is',
#   'essential',
#   'to',
#   'future',
#   'planning',
#   'synagogue',
#   'in',
#   'was',
#   'supposed',
#   'to',
#   'have',
#   'off',
#   'street',
#   'parking',
#   'but',
#   'this',
#   'has',
#   'never',
#   'been',
#   'put',
#   'into',
#   'place',
#   'by',
#   'the',
#   'acc',
#   'is',
#   'part',
#   'of',
#   'the',
#   'neighbourhood',
#   'character',
#   'but',
#   'it',
#   'is',
#   'not',
#   'shown',
#   'on',
#   'the',
#   'map',
#   'except',
#   'for',
#   'one',
#   'small',
#   'section',
#   'at',
#   'park',
#   'is',
#   'a',
#   'major',
#   'catchment',
#   'creek',
#   'to',
#   'the',
#   'and',
#   'needs',
#   'to',
#   'be',
#   'treated',
#   'as',
#   'such',
#   'and',
#   'always',
#   'considered',
#   'in',
#   'the',
#   'planning',
#   'ids',
#   'the',
#   'regeneration',
#   'of',
#   'through',
#   'happening',
#   'vegetation',
#   'protection',
#   'orders',
#   'are',
#   'in',
#   'place',
#   'in',
#   'this',
#   'area',
#   'are',
#   'some',
#   'significant',
#   'trees',
#   'within',
#   'the',
#   'area',
#   'that',
#   'need',
#   'protection',
#   'as',
#   'does',
#   'and',
#   'banks',
#   'the',
#   'acc',
#   'have',
#   'accurate',
#   'records',
#   'showing',
#   'preand',
#   'pre',
#   'houses',
#   'houses',
#   'are',
#   'expensive',
#   'to',
#   'maintain',
#   'and',
#   'essential',
#   'to',
#   'the',
#   'neighbourhood',
#   'character',
#   'what',
#   'incentives',
#   'does',
#   'the',
#   'acc',
#   'have',
#   'in',
#   'place',
#   'to',
#   'support',
#   'these',
#   'property',
#   'owners',
#   'in',
#   'maintaining',
#   'the',
#   'regions',
#   'neighbourhood',
#   'character'],
#  ['end',
#   'of',
#   'is',
#   'virtually',
#   'intact',
#   'with',
#   'predwellings',
#   'of',
#   'significant',
#   'historical',
#   'value',
#   'covering',
#   'styles',
#   'and',
#   'build',
#   'periods',
#   'from',
#   'to',
#   'pre',
#   'war',
#   'should',
#   'continue',
#   'to',
#   'be',
#   'protected',
#   'and',
#   'to',
#   'form',
#   'a',
#   'height',
#   'transition',
#   'zone',
#   'for',
#   'the',
#   'medium',
#   'density',
#   'proposed',
#   'for',
#   'the',
#   'balance',
#   'of',
#   'near',
#   'the',
#   'hospital'],
#  ['is',
#   'not',
#   'adequate',
#   'parklands',
#   'for',
#   'allowing',
#   'medium',
#   'to',
#   'high',
#   'density',
#   'developments',
#   'in',
#   'greenslopes',
#   'is',
#   'absolutely',
#   'inacceptable',
#   'should',
#   'be',
#   'focused',
#   'around',
#   'the',
#   'existing',
#   'and',
#   'road',
#   'away',
#   'from',
#   'residents',
#   'that',
#   'live',
#   'in',
#   'because',
#   'of',
#   'the',
#   'low',
#   'density',
#   'living',
#   'three',
#   'storey',
#   'developments',
#   'to',
#   'occur',
#   'in',
#   'street',
#   'and',
#   'is',
#   'also',
#   'unacceptable',
#   'the',
#   'road',
#   'are',
#   'not',
#   'built',
#   'for',
#   'the',
#   'increased',
#   'traffic',
#   'and',
#   'on',
#   'road',
#   'parking',
#   'this',
#   'would',
#   'bring',
#   'to',
#   'the',
#   'area',
#   'plan',
#   'is',
#   'called',
#   'the',
#   'plan',
#   'but',
#   'all',
#   'the',
#   'development',
#   'is',
#   'focused',
#   'on',
#   'completely',
#   'unacceptable'],
#  ['storey',
#   'developments',
#   'anywhere',
#   'in',
#   'is',
#   'not',
#   'practical',
#   'or',
#   'sustainable',
#   'storey',
#   'developments',
#   'adjoining',
#   'and',
#   'in',
#   'any',
#   'of',
#   'the',
#   'smaller',
#   'streets',
#   'other',
#   'than',
#   'along',
#   'main',
#   'roads',
#   'e',
#   'g',
#   'road',
#   'also',
#   'not',
#   'supported',
#   'or',
#   'encourage'],
#  ['character',
#   'protection',
#   'of',
#   'the',
#   'pre',
#   'houses',
#   'in',
#   'street',
#   'down',
#   'to',
#   'street',
#   'must',
#   'be',
#   'retained',
#   'street',
#   'only',
#   'ran',
#   'from',
#   'street',
#   'to',
#   'street',
#   'of',
#   'the',
#   'character',
#   'houses',
#   'are',
#   'situated',
#   'here',
#   'street',
#   'cannot',
#   'be',
#   'viewed',
#   'as',
#   'a',
#   'whole',
#   'as',
#   'the',
#   '2',
#   'ends',
#   'of',
#   'the',
#   'street',
#   'have',
#   'a',
#   'different',
#   'history',
#   'storey',
#   'units',
#   'should',
#   'be',
#   'be',
#   'allowed',
#   'in',
#   'the',
#   'to',
#   'street',
#   'section',
#   'of',
#   'street',
#   'as',
#   'they',
#   'will',
#   'tower',
#   'over',
#   'the',
#   'existing',
#   'character',
#   'houses',
#   'which',
#   'are',
#   'only',
#   '2',
#   'storey',
#   'will',
#   'protect',
#   'the',
#   'established',
#   'character',
#   'of',
#   'the',
#   'neighbourhood',
#   'existing',
#   'infill',
#   'zoning',
#   'of',
#   'this',
#   'area',
#   'should',
#   'remain'],
#  ['development',
#   'over',
#   '3',
#   'stories',
#   'is',
#   'unnecessary',
#   'and',
#   'unwanted',
#   'of',
#   'the',
#   'suburbs',
#   'character',
#   'is',
#   'paramount'],
#  ['i',
#   'strongly',
#   'disagree',
#   'with',
#   'the',
#   'proposal',
#   'to',
#   'shift',
#   'zoning',
#   'of',
#   'and',
#   'to',
#   'medium',
#   'residential',
#   'are',
#   'many',
#   'character',
#   'houses',
#   'in',
#   'these',
#   'streets',
#   'a',
#   'lot',
#   'of',
#   'them',
#   'owned',
#   'by',
#   'young',
#   'families',
#   'who',
#   'have',
#   'made',
#   'significant',
#   'investments',
#   'in',
#   'creating',
#   'a',
#   'quiet',
#   'leafy',
#   'environment',
#   'in',
#   'which',
#   'to',
#   'raise',
#   'their',
#   'children',
#   '5',
#   'storey',
#   'apartment',
#   'blocks',
#   'would',
#   'destroy',
#   'the',
#   'area',
#   'is',
#   'going',
#   'to',
#   'be',
#   'a',
#   'significant',
#   'oversupply',
#   'of',
#   'units',
#   'in',
#   'nearby',
#   'annerley',
#   'where',
#   'about',
#   '7',
#   '8',
#   'storey',
#   'blocks',
#   'next',
#   'to',
#   'the',
#   'are',
#   'about',
#   'to',
#   'come',
#   'online',
#   'add',
#   'to',
#   'the',
#   'problem'],
#  ['density',
#   'development',
#   'along',
#   'quiet',
#   'residential',
#   'streets',
#   'such',
#   'as',
#   'is',
#   'inappropriate',
#   'as',
#   '5',
#   'storeys',
#   'will',
#   'be',
#   'higher',
#   'than',
#   'many',
#   'parts',
#   'of',
#   'the',
#   'hospital',
#   'and',
#   'will',
#   'not',
#   'step',
#   'down',
#   'to',
#   'existing',
#   'residential',
#   'properties',
#   'many',
#   'of',
#   'which',
#   'are',
#   'restored',
#   'and',
#   'renovated',
#   'that',
#   'significantly',
#   'contribute',
#   'to',
#   'the',
#   'character',
#   'of',
#   'this',
#   'area'],
#  ['q3',
#   'needs',
#   'to',
#   'separate',
#   'issue',
#   'between',
#   'development',
#   'near',
#   'parks',
#   'and',
#   'development',
#   'near',
#   'logan',
#   'rd',
#   'and',
#   'hospitals',
#   'development',
#   'but',
#   'strongly',
#   'disagree',
#   'near',
#   'larger',
#   'parks',
#   'would',
#   'ruin',
#   'the',
#   'amenity',
#   'of',
#   'the',
#   'park'],
#  ['on',
#   'are',
#   'all',
#   'residential',
#   'is',
#   'no',
#   'unit',
#   'developments',
#   'of',
#   'the',
#   'houses',
#   'that',
#   'back',
#   'onot',
#   'the',
#   'parland',
#   'are',
#   'pre',
#   'need',
#   'to',
#   'be',
#   'character',
#   'protected',
#   'to',
#   'maintian',
#   'the',
#   'character',
#   'of',
#   'the',
#   'area',
#   'example',
#   'we',
#   'live',
#   'at',
#   'st',
#   'house',
#   'and',
#   'the',
#   'houses',
#   'on',
#   'either',
#   'side',
#   'are',
#   'pre',
#   'and',
#   'should',
#   'ne',
#   'be',
#   'able',
#   'to',
#   'be',
#   'demolished',
#   'or',
#   'removed',
#   'area',
#   'is',
#   'clearly',
#   'residential',
#   'housing',
#   'and',
#   'no',
#   'unit',
#   'developments',
#   'should',
#   'be',
#   'allowed',
#   'developments',
#   'should',
#   'have',
#   'orders',
#   'protecting',
#   'existing',
#   'trees',
#   'to',
#   'ensure',
#   'that',
#   'the',
#   'greenscape',
#   'of',
#   'the',
#   'neighbourhood',
#   'is',
#   'preserved'],
#  ['along',
#   'main',
#   'corridor',
#   'road',
#   'such',
#   'as',
#   'and',
#   'roads',
#   'should',
#   'all',
#   'have',
#   'character',
#   'traditional',
#   'overlay',
#   'lifted',
#   'needs',
#   'to',
#   'accept',
#   'that',
#   'to',
#   'remain',
#   'competitive',
#   'globally',
#   'we',
#   'as',
#   'a',
#   'city',
#   'need',
#   'to',
#   'change',
#   'and',
#   'grow',
#   'with',
#   'these',
#   'modern',
#   'times',
#   'i',
#   'understand',
#   'people',
#   'do',
#   'not',
#   'like',
#   'change',
#   'no',
#   'do',
#   'not',
#   'want',
#   'to',
#   'have',
#   'to',
#   'move',
#   'further',
#   'away',
#   'from',
#   'the',
#   'cbd',
#   'to',
#   'maintain',
#   'their',
#   'quieter',
#   'lifestyle',
#   'but',
#   'our',
#   'city',
#   'is',
#   'changing',
#   'and',
#   'we',
#   'all',
#   'need',
#   'to',
#   'accept',
#   'growth',
#   'needs',
#   'to',
#   'occur',
#   'to',
#   'keep',
#   'our',
#   'economy',
#   'strong',
#   'working',
#   'close',
#   'to',
#   'the',
#   'city',
#   'want',
#   'to',
#   'live',
#   'close',
#   'to',
#   'the',
#   'city',
#   'so',
#   'as',
#   'travel',
#   'time',
#   'is',
#   'reduced',
#   'this',
#   'means',
#   'and',
#   'alike',
#   'needs',
#   'to',
#   'become',
#   'denser',
#   'to',
#   'accomodate',
#   'them',
#   'then',
#   'so',
#   'be',
#   'it',
#   'as',
#   'a',
#   'city',
#   'must',
#   'remain',
#   'competitive',
#   'and',
#   'existing',
#   'residnts',
#   'need',
#   'think',
#   'about',
#   'the',
#   'whole',
#   'picture',
#   'with',
#   'all',
#   'of',
#   'the',
#   'community',
#   'in',
#   'need',
#   'and',
#   'not',
#   'just',
#   'their',
#   'own',
#   'wants',
#   'and',
#   'allow',
#   'progress',
#   'to',
#   'protect',
#   'our',
#   'children',
#   's',
#   'economical',
#   'future',
#   'and',
#   'to',
#   'let',
#   'go',
#   'and',
#   'accept',
#   'change',
#   'is',
#   'an',
#   'inevitable',
#   'part',
#   'of',
#   'today',
#   's',
#   'world'],
#  ['should',
#   'be',
#   'measures',
#   'as',
#   'larger',
#   'setbacks',
#   'to',
#   'the',
#   'rear',
#   'boundary',
#   'that',
#   'will',
#   'provide',
#   'for',
#   'new',
#   'medium',
#   'density',
#   'residential',
#   'to',
#   'create',
#   'a',
#   'sympathetic',
#   'transition',
#   'to',
#   'open',
#   'space',
#   'to',
#   'protect',
#   'amenity',
#   'of',
#   'the',
#   'open',
#   'space',
#   'parks'],
#  ['are',
#   'far',
#   'too',
#   'many',
#   'allowances',
#   'for',
#   'the',
#   'removal',
#   'or',
#   'change',
#   'of',
#   'character',
#   'housing',
#   'small',
#   'streets',
#   'cannot',
#   'cope',
#   'with',
#   'the',
#   'extra',
#   'traffic',
#   'and',
#   'the',
#   'streetscape',
#   'will',
#   'be',
#   'ruined',
#   'plan',
#   'is',
#   'disastrous',
#   'for',
#   'where',
#   'we',
#   'live',
#   'where',
#   'units',
#   'are',
#   'proposed',
#   'whole',
#   'lifestyle',
#   'will',
#   'change',
#   'can',
#   't',
#   'even',
#   'get',
#   'approval',
#   'for',
#   'a',
#   'double',
#   'carport',
#   'yet',
#   'you',
#   'are',
#   'going',
#   'to',
#   'allow',
#   '5',
#   'x',
#   '3',
#   'bedroom',
#   'units',
#   'and',
#   'that',
#   'will',
#   'only',
#   'be',
#   'the',
#   'start',
#   'of',
#   'the',
#   'destruction',
#   'whole',
#   'concept',
#   'of',
#   'what',
#   'you',
#   'are',
#   'going',
#   'to',
#   'do',
#   'to',
#   'our',
#   'immediate',
#   'area',
#   'is',
#   'disgraceful',
#   'on',
#   'the',
#   'lower',
#   'end',
#   'is',
#   'a',
#   'mess',
#   'and',
#   'almost',
#   'impossible',
#   'to',
#   'drive',
#   'through',
#   'now',
#   'because',
#   'of',
#   'the',
#   'amount',
#   'of',
#   'unit',
#   'development',
#   'and',
#   'now',
#   'you',
#   'want',
#   'to',
#   'ruin',
#   'our',
#   'street',
#   'and',
#   'adjoining',
#   'streets',
#   'as',
#   'well',
#   'are',
#   'disgusted',
#   'with',
#   'what',
#   'is',
#   'going',
#   'on',
#   'where',
#   'there',
#   'is',
#   'character',
#   'housing',
#   'intact',
#   'and',
#   'put',
#   'units',
#   'in',
#   'a',
#   'more',
#   'suitable',
#   'area'],
#  ['area',
#   'around',
#   'the',
#   'hospital',
#   'can',
#   'not',
#   'take',
#   'any',
#   'more',
#   'development',
#   'has',
#   'already',
#   'taken',
#   'the',
#   'burden',
#   'of',
#   'increased',
#   'housing',
#   'development',
#   'and',
#   'an',
#   'increase',
#   'in',
#   'the',
#   'hospital',
#   'size',
#   'energex',
#   'site',
#   'needs',
#   'to',
#   'be',
#   'developed',
#   'as',
#   'green',
#   'space',
#   'yards',
#   'fast',
#   'disappearing',
#   'all',
#   'chance',
#   'of',
#   'retaining',
#   'and',
#   'increasing',
#   'vegetation',
#   'areas',
#   'need',
#   'to',
#   'be',
#   'grabbed'],
#  ['ref',
#   '1',
#   'change',
#   'will',
#   'fragment',
#   'the',
#   'street',
#   'scape',
#   'character',
#   'of',
#   'the',
#   'surrounding',
#   'district'],
#  ['neighbourhood',
#   'character',
#   'will',
#   'best',
#   'be',
#   'preserved',
#   'by',
#   'adhering',
#   'to',
#   'a',
#   '2',
#   'storey',
#   'maximum',
#   'housing',
#   'policy',
#   'growing',
#   'more',
#   'trees',
#   'for',
#   'shade',
#   'in',
#   'streets',
#   'and',
#   'not',
#   'creating',
#   'the',
#   'haphazard',
#   'mess',
#   'that',
#   'already',
#   'has',
#   'been',
#   'caused',
#   'by',
#   'greed',
#   'just',
#   'take',
#   'a',
#   'walk',
#   'down',
#   'street'],
#  ['and',
#   'are',
#   'historical',
#   'areas',
#   'with',
#   'the',
#   'treasured',
#   'pieces',
#   'of',
#   'this',
#   'history',
#   'to',
#   'be',
#   'preserved',
#   'character',
#   'buildings',
#   'should',
#   'not',
#   'be',
#   'demolished',
#   'for',
#   'the',
#   'sake',
#   'of',
#   'investors',
#   'benefit',
#   'friendly',
#   'and',
#   'comfortable',
#   'living',
#   'established',
#   'in',
#   'the',
#   'area',
#   'must',
#   'be',
#   'retained',
#   'where',
#   'new',
#   'project',
#   'should',
#   'support',
#   'that',
#   'that',
#   'rather',
#   'than',
#   'destroy',
#   'the',
#   'current',
#   'residential',
#   'landscape'],
#  ['consultation',
#   'is',
#   'to',
#   'be',
#   'held',
#   'for',
#   'residents',
#   'living',
#   'in',
#   'street',
#   'and',
#   'neighbouring',
#   'streets',
#   'is',
#   'how',
#   'the',
# ...
#   'safety',
#   'and',
#   'use',
#   'of',
#   'parks',
#   'is',
#   'just',
#   'another',
#   'justification',
#   'for',
#   'profit',
#   'maximisation',
#   'for',
#   'developers',
#   'who',
#   'wish',
#   'to',
#   'build',
#   'developments',
#   'that',
#   'will',
#   'attract',
#   'a',
#   'higher',
#   'price',
#   'tag'],
#  ['access',
#   'to',
#   'should',
#   'be',
#   'considered',
#   'as',
#   'part',
#   'of',
#   'the',
#   'plan',
#   'often',
#   'see',
#   'cars',
#   'parked',
#   'along',
#   'the',
#   'frontage',
#   'of',
#   'this',
#   'park',
#   'which',
#   'can',
#   'be',
#   'a',
#   'safety',
#   'issue',
#   'development',
#   'of',
#   'active',
#   'use',
#   'of',
#   'this',
#   'park',
#   'should',
#   'be',
#   'considered',
#   'by',
#   'council'],
#  ['alone', 'as', 'it', 'is', 'the', 'only', 'green', 'area', 'left'],
#  ['the',
#   'proposed',
#   '5',
#   'storeys',
#   'on',
#   'and',
#   'the',
#   'hundreds',
#   'of',
#   'new',
#   'residents',
#   'this',
#   'will',
#   'bring',
#   'to',
#   'this',
#   'very',
#   'small',
#   'pocket',
#   'there',
#   'are',
#   'no',
#   'plans',
#   'for',
#   'introducing',
#   'green',
#   'spaces',
#   'parks',
#   'in',
#   'this',
#   'area'],
#  ['are',
#   'very',
#   'fortunate',
#   'to',
#   'have',
#   'green',
#   'space',
#   'around',
#   'this',
#   'area',
#   'it',
#   'must',
#   'be',
#   'preserved',
#   'and',
#   'enhanced'],
#  ['development',
#   'of',
#   'the',
#   'and',
#   'old',
#   'sites',
#   'should',
#   'not',
#   'extend',
#   'all',
#   'the',
#   'way',
#   'through',
#   'to',
#   'the',
#   'site',
#   'the',
#   'area',
#   'bouded',
#   'by',
#   'the',
#   'red',
#   'dashed',
#   'line',
#   'appears',
#   'to',
#   'include',
#   'areas',
#   'of',
#   'native',
#   'bushland',
#   'beyond',
#   'the',
#   'limits',
#   'of',
#   'the',
#   'old',
#   'quarry',
#   'site',
#   'needs',
#   'to',
#   'remain',
#   'a',
#   'substanive',
#   'native',
#   'vegetation',
#   'corrider',
#   'between',
#   'and',
#   'creek'],
#  ['backdrop',
#   'to',
#   'can',
#   'best',
#   'be',
#   'protected',
#   'by',
#   'not',
#   'setting',
#   'new',
#   'heights',
#   'such',
#   'as',
#   '5',
#   'and',
#   '8',
#   'storeys',
#   'for',
#   'new',
#   'developments',
#   'the',
#   'site',
#   'is',
#   'to',
#   'be',
#   're',
#   'developed',
#   'it',
#   'should',
#   'be',
#   'identified',
#   'as',
#   'low',
#   'medium',
#   'density',
#   'residential',
#   'to',
#   'fit',
#   'with',
#   'surrounding',
#   'residential',
#   'streets'],
#  ['21',
#   'i',
#   'would',
#   'need',
#   'to',
#   'know',
#   'exactly',
#   'where',
#   'this',
#   'would',
#   'be',
#   'to',
#   'be',
#   'able',
#   'to',
#   'comment'],
#  ['section',
#   'is',
#   'on',
#   'fully',
#   'understood',
#   'or',
#   'explained',
#   'and',
#   'therefore',
#   'difficult',
#   'to',
#   'respond',
#   'needs',
#   'to',
#   'be',
#   'given',
#   'to',
#   'facilities',
#   'and',
#   'culture',
#   'of',
#   'the',
#   'area',
#   'jus',
#   'servicing',
#   'the',
#   'hospital'],
#  ['agree',
#   'with',
#   'proposed',
#   'plans',
#   'that',
#   'will',
#   'enhance',
#   'current',
#   'green',
#   'areas',
#   'and',
#   'ensure',
#   'retains',
#   'its',
#   'outdoor',
#   'spaces',
#   'and',
#   'lifestyle'],
#  ['q',
#   'very',
#   'ambiguous',
#   'are',
#   'appropriate',
#   'building',
#   'heights',
#   'for',
#   'new',
#   'development',
#   'it',
#   'is',
#   'no',
#   'greater',
#   'than',
#   '2',
#   'stories',
#   'my',
#   'answer',
#   'is',
#   'as',
#   'ticked'],
#  ['are',
#   'important',
#   'not',
#   'only',
#   'that',
#   'it',
#   'is',
#   'important',
#   'they',
#   'are',
#   'not',
#   'hidden',
#   'behind',
#   'walls',
#   'of',
#   'high',
#   'rise',
#   'of',
#   '5',
#   'storey',
#   'as',
#   'indicated',
#   'for',
#   'park'],
#  ['acc',
#   'consult',
#   'liaise',
#   'with',
#   'views',
#   'of',
#   'local',
#   'communities',
#   'when',
#   'where',
#   'development',
#   'is',
#   'planned'],
#  ['i',
#   'do',
#   'not',
#   'think',
#   'there',
#   'is',
#   'any',
#   'need',
#   'for',
#   'coffee',
#   'shops',
#   'to',
#   'be',
#   'in',
#   'parks',
#   'are',
#   'plenty',
#   'of',
#   'lively',
#   'centres',
#   'for',
#   'people',
#   'to',
#   'pick',
#   'up',
#   'a',
#   'coffee',
#   'and',
#   'then',
#   'go',
#   'to',
#   'the',
#   'park',
#   'a',
#   'park',
#   'as',
#   'a',
#   'park',
#   'please'],
#  ['need',
#   'a',
#   'dog',
#   'park',
#   'in',
#   'the',
#   'precinct',
#   'of',
#   'st',
#   'area',
#   'are',
#   '2',
#   'parks',
#   'here',
#   'where',
#   'a',
#   'small',
#   'dog',
#   'park',
#   'could',
#   'be',
#   'included',
#   'at',
#   'the',
#   'park',
#   'in',
#   'behind',
#   'the',
#   'shops',
#   'are',
#   'appealing',
#   'sails',
#   'are',
#   'needed',
#   'and',
#   'a',
#   'new',
#   'drinking',
#   'fountain',
#   'and',
#   'dog',
#   'water',
#   'bowl',
#   'at',
#   'the',
#   'tap',
#   'has',
#   'been',
#   'done',
#   'to',
#   'this',
#   'popular',
#   'park',
#   'for',
#   'years',
#   'up',
#   'council',
#   'and',
#   'do',
#   'something',
#   'about',
#   'this',
#   'live',
#   'in',
#   'this',
#   'expensive',
#   'area',
#   'and',
#   'have',
#   'poor',
#   'park',
#   'facilities',
#   'compared',
#   'to',
#   'other',
#   'areas',
#   'like',
#   'the',
#   'park',
#   'in',
#   'hill',
#   'has',
#   'had',
#   'huge',
#   'dollars',
#   'spent',
#   'on',
#   'it',
#   'area',
#   'has',
#   'had',
#   'almost',
#   'no',
#   'park',
#   'upgrades',
#   'except',
#   'recently'],
#  ['19',
#   'to',
#   'be',
#   'changed',
#   'if',
#   'of',
#   'when',
#   'move',
#   '23',
#   'alone',
#   'is',
#   'no',
#   'green',
#   'space',
#   'in',
#   'the',
#   'centre',
#   'of',
#   'this',
#   'area',
#   'it',
#   'is',
#   'a',
#   '10',
#   'minute',
#   'walk',
#   'to',
#   'any',
#   'park'],
#  ['new',
#   'development',
#   'should',
#   'not',
#   'remove',
#   'current',
#   'habitat',
#   'for',
#   'native',
#   'animals',
#   'as',
#   'well',
#   'as',
#   'respecting',
#   'the',
#   'current',
#   'life',
#   'stile',
#   'of',
#   'the',
#   'residence',
#   'in',
#   'the',
#   'area',
#   'restrictions',
#   'should',
#   'be',
#   'restricted',
#   'to',
#   'ensure',
#   'that',
#   'the',
#   'current',
#   'character',
#   'of',
#   'the',
#   'area',
#   'is',
#   'maintained'],
#  ['park',
#   'and',
#   'entertainment',
#   'facilties',
#   'exist',
#   'today',
#   'open',
#   'space',
#   'we',
#   'have',
#   'supports',
#   'such',
#   'a',
#   'range',
#   'of',
#   'activity',
#   'that',
#   'reflects',
#   'the',
#   'councils',
#   'desire',
#   'to',
#   'build',
#   'community',
#   'and',
#   'green',
#   'leafy',
#   'in',
#   'a',
#   'flood',
#   'zone',
#   'i',
#   'think',
#   'the',
#   'infrastructure',
#   'ideas',
#   'here',
#   'foolish',
#   'and',
#   'cost',
#   'ineffeictve'],
#  ['about',
#   'a',
#   'dog',
#   'off',
#   'leash',
#   'park',
#   'at',
#   'estate',
#   'hear',
#   'arguments',
#   'that',
#   'they',
#   'get',
#   'washed',
#   'away',
#   'during',
#   'floods',
#   'but',
#   'fences',
#   'have',
#   'been',
#   'built',
#   'around',
#   'children',
#   's',
#   'play',
#   'areas',
#   'in',
#   'more',
#   'or',
#   'less',
#   'the',
#   'same',
#   'location'],
#  ['owing',
#   'to',
#   'its',
#   'bushland',
#   'and',
#   'green',
#   'landmark',
#   'attributes',
#   'any',
#   'improvements',
#   'should',
#   'be',
#   'only',
#   'of',
#   'a',
#   'low',
#   'key',
#   'nature',
#   'or',
#   'permanent',
#   'structures',
#   'such',
#   'as',
#   'cafes',
#   'should',
#   'remain',
#   'outside',
#   'park',
#   'boundaries',
#   'in',
#   'order',
#   'to',
#   'preserve',
#   'valuable',
#   'green',
#   'space'],
#  ['area',
#   'proposed',
#   'to',
#   'be',
#   'linked',
#   'is',
#   'not',
#   'really',
#   'easily',
#   'accessible',
#   'to',
#   'many',
#   'people',
#   'in',
#   'the',
#   'area',
#   'the',
#   'proposal',
#   'to',
#   'put',
#   'commercial',
#   'and',
#   'further',
#   'equipment',
#   'into',
#   'exiting',
#   'parks',
#   'is',
#   'the',
#   'opposite',
#   'of',
#   'greening',
#   'is',
#   'the',
#   'requirement',
#   'for',
#   'developers',
#   'to',
#   'provide',
#   'micro',
#   'parks',
#   'when',
#   'they',
#   'develop',
#   'large',
#   'areas',
#   'of',
#   'land',
#   'where',
#   'are',
#   'the',
#   'proposals',
#   'for',
#   'improved',
#   'toilet',
#   'facilities',
#   'which',
#   'are',
#   'necessary',
#   'for',
#   'many',
#   'people',
#   'including',
#   'myself',
#   'to',
#   'fully',
#   'benefit',
#   'from',
#   'open',
#   'space',
#   'etc',
#   'etc',
#   'innovative',
#   'approaches',
#   'at',
#   'all',
#   'just',
#   'a',
#   'proposal',
#   'to',
#   'tweak',
#   'existing',
#   'areas',
#   'and',
#   'add',
#   'some',
#   'commercial',
#   'development'],
#  ['i',
#   'agree',
#   'that',
#   'there',
#   'should',
#   'be',
#   'access',
#   'to',
#   'mountain',
#   'as',
#   'this',
#   'would',
#   'be',
#   'a',
#   'great',
#   'bushwalking',
#   'area',
#   'play',
#   'equipment',
#   'is',
#   'definitely',
#   'needed',
#   'at',
#   'estate',
#   'and',
#   'more',
#   'coffee',
#   'shops',
#   'and',
#   'even',
#   'carts',
#   'would',
#   'be',
#   'great'],
#  ['strategy',
#   'and',
#   'goals',
#   'around',
#   'improving',
#   'greenspace',
#   'and',
#   'corridors',
#   'appears',
#   'favourable',
#   'but',
#   'it',
#   'does',
#   'not',
#   'seem',
#   'that',
#   'these',
#   'intentions',
#   'are',
#   'being',
#   'realised',
#   'within',
#   'the',
#   'proposed',
#   'mapping',
#   'and',
#   'zoning',
#   'across',
#   'the',
#   'area',
#   'stephen',
#   's',
#   'should',
#   'be',
#   'regenerated',
#   'not',
#   'developed',
#   'highlighting',
#   'the',
#   'imbalance',
#   'between',
#   'the',
#   'proposed',
#   'increases',
#   'in',
#   'densities',
#   'and',
#   'failure',
#   'to',
#   'protect',
#   'natural',
#   'assets',
#   '5',
#   'story',
#   'apartments',
#   'contradicts',
#   'the',
#   'conservation',
#   'of',
#   'all',
#   'things',
#   'green',
#   'natural',
#   'assets',
#   'and',
#   'the',
#   'creation',
#   'of',
#   'natural',
#   'corridors',
#   'should',
#   'be',
#   'nurtured',
#   'and',
#   'the',
#   'establishment',
#   'of',
#   'more',
#   'useable',
#   'greenspace',
#   'such',
#   'as',
#   'parklands',
#   'and',
#   'sporting',
#   'facilities',
#   'should',
#   'be',
#   'a',
#   'focus',
#   'if',
#   'we',
#   'are',
#   'talking',
#   'about',
#   'community',
#   'and',
#   'planning',
#   'the',
#   'population',
#   'and',
#   'density',
#   'in',
#   'an',
#   'area',
#   'that',
#   'is',
#   'already',
#   'incapable',
#   'of',
#   'sustaining',
#   'what',
#   'it',
#   'currently',
#   'has',
#   'appears',
#   'to',
#   'be',
#   'poor',
#   'planning',
#   'and',
#   'a',
#   'total',
#   'disregards',
#   'to',
#   'the',
#   'existing',
#   'community',
#   'who',
#   'have',
#   'purchased',
#   'homes',
#   'pay',
#   'council',
#   'rates',
#   'that',
#   'facilitate',
#   'these',
#   'proposed',
#   'plans',
#   'for',
#   'our',
#   'neighbourhood',
#   'yet',
#   'the',
#   'initial',
#   'plans',
#   'are',
#   'not',
#   'a',
#   'reflection',
#   'of',
#   'the',
#   'community',
#   'then',
#   'or',
#   'now',
#   'alone',
#   'the',
#   'community',
#   'knowledge',
#   'of',
#   'identified',
#   'flood',
#   'areas',
#   'predominately',
#   'near',
#   'roundabout',
#   'went',
#   'under',
#   'in',
#   'flood',
#   'and',
#   'once',
#   'since',
#   'then',
#   'at',
#   'least',
#   'to',
#   'the',
#   'degree',
#   'it',
#   'caused',
#   'road',
#   'closure',
#   'and',
#   'traffic',
#   'diversion',
#   'about',
#   'the',
#   'way',
#   'the',
#   'sewage',
#   'pipes',
#   'etc',
#   'are',
#   'established',
#   'in',
#   'the',
#   'area',
#   'that',
#   'has',
#   'been',
#   'a',
#   'diversion',
#   'to',
#   'previous',
#   'development',
#   'being',
#   'stopped'],
#  ['relation',
#   'to',
#   'no',
#   '23',
#   'appropriate',
#   'building',
#   'heights',
#   'should',
#   'be',
#   'should',
#   'be',
#   'set',
#   'at',
#   'max',
#   '1',
#   'storey',
#   'to',
#   'ensure',
#   'the',
#   'view',
#   'of',
#   'residents',
#   'of',
#   'stephens',
#   'mountain',
#   'is',
#   'not',
#   'compromised'],
#  ['and',
#   'maintenance',
#   'weed',
#   'removal',
#   'along',
#   'the',
#   'walkway',
#   'around',
#   'mountain'],
#  ['to',
#   'keep',
#   'our',
#   'neighbourhood',
#   'green',
#   'open',
#   'which',
#   'is',
#   'consistent',
#   'with',
#   'small',
#   'scale',
#   'developments',
#   'no',
#   'more',
#   'than',
#   '3',
#   'storey'],
#  ['coffee',
#   'and',
#   'facilities',
#   'at',
#   'the',
#   'already',
#   'exist',
#   'ie',
#   'the',
#   'cafe',
#   'is',
#   'needed',
#   'there',
#   'is',
#   'a',
#   'complete',
#   'overhall',
#   'of',
#   'the',
#   'play',
#   'ground',
#   'next',
#   'to',
#   'it',
#   'with',
#   'more',
#   'sensitive',
#   'and',
#   'robust',
#   'surfaces',
#   'n4c',
#   'also',
#   'has',
#   'an',
#   'espresso',
#   'machine',
#   'next',
#   'to',
#   'its',
#   'nursery',
#   'but',
#   'is',
#   'underutilised',
#   'parks',
#   'interface',
#   'with',
#   'the',
#   'bowls',
#   'club',
#   'should',
#   'be',
#   'investigated',
#   'there',
#   'is',
#   'good',
#   'scope',
#   'to',
#   'do',
#   'something',
#   'exceptional',
#   'please',
#   'implement',
#   'the',
#   'we',
#   'have',
#   'been',
#   'waiting',
#   '4',
#   'years',
#   'now',
#   'for',
#   'any',
#   'word',
#   'of',
#   'the',
#   'next',
#   'steps',
#   'is',
#   'a',
#   'priority',
#   'project',
#   'and',
#   'it',
#   'has',
#   'not',
#   'been',
#   'taken',
#   'up'],
#  ['the', 'green', 'in'],
#  ['development',
#   'around',
#   'stephens',
#   'mountain',
#   'park',
#   'is',
#   'needed',
#   'if',
#   'nearby',
#   'densities',
#   'are',
#   'going',
#   'to',
#   'increase',
#   'should',
#   'be',
#   'no',
#   'development',
#   'on',
#   'the',
#   'park'],
#  ['need',
#   'more',
#   'than',
#   'corridor',
#   'parks',
#   'need',
#   'more',
#   'larger',
#   'parks',
#   'that',
#   'can',
#   'be',
#   'enjoyed',
#   'away',
#   'from',
#   'inner',
#   'city',
#   'development'],
#  ['plan',
#   'has',
#   'some',
#   'provision',
#   'for',
#   'all',
#   'things',
#   'green',
#   'but',
#   'not',
#   'enough',
#   'could',
#   'be',
#   'done',
#   'to',
#   'build',
#   'new',
#   'larger',
#   'parks',
#   'for',
#   'the',
#   'increased',
#   'population'],
#  ['to',
#   'need',
#   'to',
#   'be',
#   'the',
#   'greenspace',
#   'not',
#   'more',
#   'building',
#   'no',
#   'greenspace',
#   'should',
#   'be',
#   'lost',
#   'to',
#   'building',
#   'at',
#   'all',
#   'the',
#   'energex',
#   'site',
#   'will',
#   'need',
#   'to',
#   'be',
#   'for',
#   'community',
#   'use',
#   'not',
#   'more',
#   'dwellings',
#   'we',
#   'need',
#   'to',
#   'increase',
#   'community',
#   'space',
#   'with',
#   'all',
#   'this',
#   'extra',
#   'population',
#   'that',
#   'will',
#   'have',
#   'no',
#   'backyards',
#   'to',
#   'hang',
#   'out',
#   'in',
#   'encouraging',
#   'cafes',
#   'is',
#   'good',
#   'please',
#   'please',
#   'be',
#   'careful',
#   'with',
#   'mobile',
#   'food',
#   'coffee',
#   'carts',
#   'or',
#   'food',
#   'trucks',
#   'this',
#   'is',
#   'a',
#   'sure',
#   'fire',
#   'way',
#   'to',
#   'undermine',
#   'bricks',
#   'and',
#   'mortar',
#   'business',
#   'and',
#   'acc',
#   'seems',
#   'to',
#   'completely',
#   'not',
#   'understand',
#   'this',
#   'at',
#   'the',
#   'moment',
#   'someone',
#   'has',
#   'just',
#   'spent',
#   's',
#   'fitting',
#   'out',
#   'a',
#   'cafe',
#   'and',
#   'employing',
#   'people',
#   'don',
#   't',
#   'allow',
#   'a',
#   'coffee',
#   'cart',
#   '50m',
#   'away',
#   'not',
#   'even',
#   'at',
#   'peak',
#   'times',
#   'that',
#   's',
#   'when',
#   'those',
#   'fledgling',
#   'businesses',
#   'stand',
#   'a',
#   'chance',
#   'of',
#   'breaking',
#   'even',
#   'to',
#   'estate',
#   'park',
#   'please',
#   'no',
#   'point',
#   'adding',
#   'the',
#   'rest',
#   'if',
#   'they',
#   'aren',
#   't',
#   'there',
#   'park',
#   'between',
#   'and',
#   'cornwall',
#   'please',
#   'sort',
#   'out',
#   'the',
#   'cricket',
#   'pitch',
#   'add',
#   'toilets',
#   'cafe',
#   'it',
#   'll',
#   'be',
#   'fab',
#   'morning',
#   'spot',
#   'in',
#   'the',
#   'summer'],
#  ['you', 'not', 'have', 'development', 'near', 'or', 'cb', 'park'],
#  ['trees',
#   'need',
#   'better',
#   'care',
#   'as',
#   'many',
#   'die',
#   'as',
#   'not',
#   'watered',
#   'consider',
#   'programme',
#   'that',
#   'ratepayers',
#   'get',
#   '100',
#   'discount',
#   'of',
#   'rates',
#   'per',
#   'year',
#   'if',
#   'tree',
#   'on',
#   'their',
#   'footpath',
#   'is',
#   'alive',
#   'and',
#   'healthy',
#   'keep',
#   'mountain',
#   'as',
#   'a',
#   'green',
#   'space',
#   'and',
#   'not',
#   'developed'],
#  ['the',
#   'number',
#   'of',
#   'young',
#   'families',
#   'and',
#   'couples',
#   'moving',
#   'into',
#   'the',
#   'area',
#   'there',
#   'is',
#   'an',
#   'increase',
#   'of',
#   'dog',
#   'ownership',
#   'in',
#   'the',
#   'neighbourhood',
#   'for',
#   'more',
#   'dog',
#   'parks',
#   'should',
#   'be',
#   'included',
#   'alongside',
#   'existing',
#   'playground',
#   'areas',
#   'and',
#   'in',
#   'green',
#   'space',
#   'which',
#   'are',
#   'going',
#   'mostly',
#   'unused',
#   'example',
#   'of',
#   'an',
#   'ideal',
#   'space',
#   'is',
#   'park',
#   'i',
#   'have',
#   'spoken',
#   'with',
#   'many',
#   'residents',
#   'in',
#   'the',
#   'area',
#   'which',
#   'would',
#   'use',
#   'this',
#   'area',
#   'more',
#   'if',
#   'a',
#   'dog',
#   'park',
#   'was',
#   'constructed',
#   'residents',
#   'are',
#   'driving',
#   'to',
#   'other',
#   'suburbs',
#   'to',
#   'access',
#   'dog',
#   'parks',
#   'at',
#   'present'],
#  ['that',
#   'and',
#   'prioritise',
#   'actions',
#   'contained',
#   'within',
#   'the',
#   'for',
#   'the',
#   'and',
#   'improve',
#   'safety',
#   'of',
#   'cycling',
#   'to',
#   'the',
#   'park',
#   'as',
#   'part',
#   'of',
#   'this',
#   'plan']]

# %%
#read_pretrained model
filename = r'D:\Blackbook.ai\BCC_Neighborhood_NLP\GoogleNews-vectors-negative300.bin'
word2vec = read_word2vec(filename)

# %%
index2word = {token_index:token for token_index, token in enumerate(word2vec.index2word)} 
word2index = {token:token_index for token_index, token in enumerate(word2vec.index2word)}

# %%
index2word
# Out:
# {0: '</s>',
#  1: 'in',
#  2: 'for',
#  3: 'that',
#  4: 'is',
#  5: 'on',
#  6: '##',
#  7: 'The',
#  8: 'with',
#  9: 'said',
#  10: 'was',
#  11: 'the',
#  12: 'at',
#  13: 'not',
#  14: 'as',
#  15: 'it',
#  16: 'be',
#  17: 'from',
#  18: 'by',
#  19: 'are',
#  20: 'I',
#  21: 'have',
#  22: 'he',
#  23: 'will',
#  24: 'has',
#  25: '####',
#  26: 'his',
#  27: 'an',
#  28: 'this',
#  29: 'or',
#  30: 'their',
#  31: 'who',
#  32: 'they',
#  33: 'but',
#  34: '$',
#  35: 'had',
#  36: 'year',
#  37: 'were',
#  38: 'we',
#  39: 'more',
#  40: '###',
#  41: 'up',
#  42: 'been',
#  43: 'you',
#  44: 'its',
#  45: 'one',
#  46: 'about',
#  47: 'would',
#  48: 'which',
#  49: 'out',
#  50: 'can',
#  51: 'It',
#  52: 'all',
#  53: 'also',
#  54: 'two',
#  55: 'after',
#  56: 'first',
#  57: 'He',
#  58: 'do',
#  59: 'time',
#  60: 'than',
#  61: 'when',
#  62: 'We',
#  63: 'over',
#  64: 'last',
#  65: 'new',
#  66: 'other',
#  67: 'her',
#  68: 'people',
#  69: 'into',
#  70: 'In',
#  71: 'our',
#  72: 'there',
#  73: 'A',
#  74: 'she',
#  75: 'could',
#  76: 'just',
#  77: 'years',
#  78: 'some',
#  79: 'U.S.',
#  80: 'three',
#  81: 'million',
#  82: 'them',
#  83: 'what',
#  84: 'But',
#  85: 'so',
#  86: 'no',
#  87: 'like',
#  88: 'if',
#  89: 'only',
#  90: 'percent',
#  91: 'get',
#  92: 'did',
#  93: 'him',
#  94: 'game',
#  95: 'back',
#  96: 'because',
#  97: 'now',
#  98: '#.#',
#  99: 'before',
#  100: 'company',
#  101: 'any',
#  102: 'team',
#  103: 'against',
#  104: 'off',
#  105: 'This',
#  106: 'most',
#  107: 'made',
#  108: 'through',
#  109: 'make',
#  110: 'second',
#  111: 'state',
#  112: 'well',
#  113: 'day',
#  114: 'season',
#  115: 'says',
#  116: 'week',
#  117: 'where',
#  118: 'while',
#  119: 'down',
#  120: 'being',
#  121: 'government',
#  122: 'your',
#  123: '#-#',
#  124: 'home',
#  125: 'going',
#  126: 'my',
#  127: 'good',
#  128: 'They',
#  129: "'re",
#  130: 'should',
#  131: 'many',
#  132: 'way',
#  133: 'those',
#  134: 'four',
#  135: 'during',
#  136: 'such',
#  137: 'may',
#  138: 'very',
#  139: 'how',
#  140: 'since',
#  141: 'work',
#  142: 'take',
#  143: 'including',
#  144: 'high',
#  145: 'then',
#  146: '%',
#  147: 'next',
#  148: '#,###',
#  149: 'By',
#  150: 'much',
#  151: 'still',
#  152: 'go',
#  153: 'think',
#  154: 'old',
#  155: 'even',
#  156: '#.##',
#  157: 'world',
#  158: 'see',
#  159: 'say',
#  160: 'business',
#  161: 'five',
#  162: 'told',
#  163: 'under',
#  164: 'us',
#  165: '1',
#  166: 'these',
#  167: 'If',
#  168: 'right',
#  169: 'And',
#  170: 'me',
#  171: 'between',
#  172: 'play',
#  173: 'help',
#  174: '##,###',
#  175: 'market',
#  176: 'That',
#  177: 'know',
#  178: 'end',
#  179: 'AP',
#  180: 'long',
#  181: 'information',
#  182: 'points',
#  183: 'does',
#  184: 'both',
#  185: 'There',
#  186: 'part',
#  187: 'around',
#  188: 'police',
#  189: 'want',
#  190: "'ve",
#  191: 'based',
#  192: 'For',
#  193: 'got',
#  194: 'third',
#  195: 'school',
#  196: 'left',
#  197: 'another',
#  198: 'country',
#  199: 'need',
#  200: '2',
#  201: 'best',
#  202: 'win',
#  203: 'quarter',
#  204: 'use',
#  205: 'today',
#  206: '##.#',
#  207: 'same',
#  208: 'public',
#  209: 'run',
#  210: 'Friday',
#  211: 'set',
#  212: 'month',
#  213: 'top',
#  214: 'billion',
#  215: 'Tuesday',
#  216: 'come',
#  217: 'Monday',
#  218: 'She',
#  219: 'city',
#  220: 'place',
#  221: 'night',
#  222: 'six',
#  223: 'each',
#  224: 'Thursday',
#  225: '###,###',
#  226: 'Wednesday',
#  227: 'here',
#  228: 'You',
#  229: 'group',
#  230: 'really',
#  231: 'found',
#  232: 'As',
#  233: 'used',
#  234: '3',
#  235: 'lot',
#  236: "'m",
#  237: 'money',
#  238: 'put',
#  239: 'games',
#  240: 'support',
#  241: 'program',
#  242: 'half',
#  243: 'report',
#  244: 'family',
#  245: 'months',
#  246: 'number',
#  247: 'officials',
#  248: 'am',
#  249: 'former',
#  250: 'own',
#  251: 'man',
#  252: 'Saturday',
#  253: 'too',
#  254: 'better',
#  255: 'days',
#  256: 'came',
#  257: 'lead',
#  258: 'life',
#  259: 'American',
#  260: '##-##',
#  261: 'show',
#  262: 'past',
#  263: 'took',
#  264: 'added',
#  265: 'expected',
#  266: 'called',
#  267: 'great',
#  268: 'State',
#  269: 'services',
#  270: 'children',
#  271: 'hit',
#  272: 'area',
#  273: 'system',
#  274: 'every',
#  275: 'pm',
#  276: 'big',
#  277: 'service',
#  278: 'few',
#  279: 'per',
#  280: 'members',
#  281: 'Sunday',
#  282: 'early',
#  283: 'point',
#  284: 'start',
#  285: 'companies',
#  286: 'little',
#  287: '&',
#  288: 'case',
#  289: 'ago',
#  290: 'local',
#  291: 'according',
#  292: 'never',
#  293: '5',
#  294: 'without',
#  295: 'sales',
#  296: 'until',
#  297: 'went',
#  298: 'players',
#  299: '##th',
#  300: 'New_York',
#  301: 'won',
#  302: 'financial',
#  303: 'news',
#  304: '4',
#  305: 'When',
#  306: 'share',
#  307: 'several',
#  308: 'free',
#  309: 'away',
#  310: '##.##',
#  311: 'already',
#  312: 'On',
#  313: 'industry',
#  314: "'ll",
#  315: 'call',
#  316: 'With',
#  317: 'students',
#  318: 'line',
#  319: 'available',
#  320: 'County',
#  321: 'making',
#  322: 'held',
#  323: 'final',
#  324: '#:##',
#  325: 'power',
#  326: 'plan',
#  327: 'might',
#  328: 'least',
#  329: 'look',
#  330: 'forward',
#  331: 'give',
#  332: 'At',
#  333: 'again',
#  334: 'later',
#  335: 'full',
#  336: 'must',
#  337: 'things',
#  338: 'major',
#  339: 'community',
#  340: 'announced',
#  341: 'open',
#  342: 'record',
#  343: 'reported',
#  344: 'court',
#  345: 'working',
#  346: 'able',
#  347: 'something',
#  348: 'president',
#  349: 'meeting',
#  350: 'keep',
#  351: 'March',
#  352: 'future',
#  353: 'far',
#  354: 'deal',
#  355: 'City',
#  356: 'May',
#  357: 'development',
#  358: 'University',
#  359: 'find',
#  360: 'times',
#  361: 'After',
#  362: 'office',
#  363: 'led',
#  364: 'among',
#  365: 'June',
#  366: 'increase',
#  367: 'China',
#  368: 'John',
#  369: 'whether',
#  370: 'cost',
#  371: 'security',
#  372: 'job',
#  373: 'less',
#  374: 'head',
#  375: 'seven',
#  376: 'growth',
#  377: 'lost',
#  378: 'pay',
#  379: 'looking',
#  380: 'provide',
#  381: '6',
#  382: 'To',
#  383: 'plans',
#  384: 'products',
#  385: 'car',
#  386: 'recent',
#  387: 'hard',
#  388: 'always',
#  389: 'include',
#  390: 'women',
#  391: 'across',
#  392: 'tax',
#  393: 'water',
#  394: 'April',
#  395: 'continue',
#  396: 'important',
#  397: 'different',
#  398: 'close',
#  399: '7',
#  400: 'One',
#  401: 'late',
#  402: 'decision',
#  403: 'current',
#  404: 'law',
#  405: 'within',
#  406: 'along',
#  407: 'played',
#  408: 'move',
#  409: 'United_States',
#  410: 'enough',
#  411: 'become',
#  412: 'side',
#  413: 'national',
#  414: 'Inc.',
#  415: 'results',
#  416: 'level',
#  417: 'loss',
#  418: 'economic',
#  419: 'coach',
#  420: 'near',
#  421: 'getting',
#  422: 'price',
#  423: 'Department',
#  424: 'event',
#  425: 'fourth',
#  426: 'change',
#  427: 'All',
#  428: 'small',
#  429: 'board',
#  430: 'National',
#  431: 'So',
#  432: 'goal',
#  433: 'taken',
#  434: 'field',
#  435: 'prices',
#  436: 'weeks',
#  437: 'men',
#  438: 'asked',
#  439: 'eight',
#  440: 'data',
#  441: 'shot',
#  442: 'New',
#  443: 'started',
#  444: 'July',
#  445: 'director',
#  446: 'President',
#  447: 'party',
#  448: 'federal',
#  449: 'done',
#  450: 'political',
#  451: 'minutes',
#  452: 'taking',
#  453: 'Company',
#  454: 'technology',
#  455: 'project',
#  456: 'center',
#  457: 'leading',
#  458: 'issue',
#  459: 'though',
#  460: 'having',
#  461: 'period',
#  462: 'likely',
#  463: 'scored',
#  464: '8',
#  465: 'strong',
#  466: 'series',
#  467: 'military',
#  468: 'seen',
#  469: 'trying',
#  470: 'What',
#  471: 'coming',
#  472: 'process',
#  473: 'building',
#  474: 'behind',
#  475: 'performance',
#  476: 'management',
#  477: 'Iraq',
#  478: 'saying',
#  479: 'earlier',
#  480: 'believe',
#  481: 'oil',
#  482: 'given',
#  483: 'Police',
#  484: 'customers',
#  485: 'due',
#  486: 'following',
#  487: 'term',
#  488: 'others',
#  489: 'statement',
#  490: 'international',
#  491: 'economy',
#  492: 'health',
#  493: 'thing',
#  494: 'Obama',
#  495: 'return',
#  496: 'killed',
#  497: 'Washington',
#  498: 'further',
#  499: 'However',
#  500: 'doing',
#  501: 'face',
#  502: 'low',
#  503: 'higher',
#  504: 'site',
#  505: 'once',
#  506: 'yet',
#  507: 'hours',
#  508: 'America',
#  509: 'control',
#  510: 'received',
#  511: 'rate',
#  512: 'career',
#  513: 'Bush',
#  514: 'teams',
#  515: 'known',
#  516: 'offer',
#  517: 'race',
#  518: 'ever',
#  519: 'experience',
#  520: 'playing',
#  521: 'name',
#  522: 'possible',
#  523: 'countries',
#  524: 'Mr.',
#  525: 'average',
#  526: 'together',
#  527: 'using',
#  528: '9',
#  529: 'cut',
#  530: 'While',
#  531: 'total',
#  532: 'round',
#  533: 'young',
#  534: 'nearly',
#  535: 'shares',
#  536: 'member',
#  537: 'campaign',
#  538: 'media',
#  539: 'needs',
#  540: 'why',
#  541: 'house',
#  542: 'issues',
#  543: 'costs',
#  544: 'fire',
#  545: '##-#',
#  546: 'victory',
#  547: 'player',
#  548: 'began',
#  549: 'sure',
#  550: 'story',
#  551: 'per_cent',
#  552: 'North',
#  553: 'His',
#  554: 'staff',
#  555: 'order',
#  556: 'war',
#  557: 'large',
#  558: 'interest',
#  559: 'stock',
#  560: 'food',
#  561: 'research',
#  562: 'key',
#  563: 'India',
#  564: 'South',
#  565: 'morning',
#  566: 'conference',
#  567: 'senior',
#  568: 'global',
#  569: 'Center',
#  570: 'death',
#  571: 'person',
#  572: 'thought',
#  573: 'gave',
#  574: 'feel',
#  575: 'energy',
#  576: 'history',
#  577: 'recently',
#  578: 'largest',
#  579: 'No.',
#  580: 'general',
#  581: 'official',
#  582: 'released',
#  583: 'wanted',
#  584: 'meet',
#  585: 'short',
#  586: 'outside',
#  587: 'running',
#  588: 'live',
#  589: 'ball',
#  590: 'online',
#  591: 'real',
#  592: 'position',
#  593: 'fact',
#  594: 'fell',
#  595: 'nine',
#  596: 'December',
#  597: 'front',
#  598: 'action',
#  599: 'defense',
#  600: 'problem',
#  601: 'problems',
#  602: 'Mr',
#  603: 'nation',
#  604: 'needed',
#  605: 'special',
#  606: 'January',
#  607: 'almost',
#  608: 'chance',
#  609: "'d",
#  610: 'result',
#  611: 'West',
#  612: 'September',
#  613: 'reports',
#  614: 'leader',
#  615: 'investment',
#  616: 'yesterday',
#  617: 'Some',
#  618: 'leaders',
#  619: 'ahead',
#  620: 'production',
#  621: 'comes',
#  622: 'No',
#  623: 'runs',
#  624: 'match',
#  625: 'role',
#  626: 'kind',
#  627: 'try',
#  628: 'ended',
#  629: 'risk',
#  630: 'areas',
#  631: 'election',
#  632: 'workers',
#  633: 'visit',
#  634: 'bring',
#  635: 'road',
#  636: 'music',
#  637: 'study',
#  638: 'makes',
#  639: 'often',
#  640: 'release',
#  641: 'woman',
#  642: 'vote',
#  643: 'care',
#  644: 'town',
#  645: 'clear',
#  646: 'comment',
#  647: 'budget',
#  648: 'potential',
#  649: 'single',
#  650: 'markets',
#  651: 'policy',
#  652: 'capital',
#  653: 'saw',
#  654: 'access',
#  655: 'weekend',
#  656: 'operations',
#  657: 'whose',
#  658: 'net',
#  659: 'House',
#  660: 'hand',
#  661: 'increased',
#  662: 'charges',
#  663: 'winning',
#  664: 'trade',
#  665: 'These',
#  666: 'income',
#  667: 'value',
#  668: 'involved',
#  669: 'Bank',
#  670: 'November',
#  671: 'bill',
#  672: 'compared',
#  673: 'anything',
#  674: 'manager',
#  675: 'Texas',
#  676: 'property',
#  677: 'stop',
#  678: 'annual',
#  679: 'private',
#  680: 'contract',
#  681: 'died',
#  682: 'Now',
#  683: 'hope',
#  684: 'product',
#  685: 'fans',
#  686: 'lower',
#  687: 'demand',
#  688: 'News',
#  689: 'David',
#  690: 'club',
#  691: 'comments',
#  692: 'film',
#  693: 'yards',
#  694: 'quality',
#  695: 'currently',
#  696: 'events',
#  697: 'addition',
#  698: 'couple',
#  699: 'schools',
#  700: 'attack',
#  701: 'region',
#  702: 'latest',
#  703: 'opportunity',
#  704: 'worked',
#  705: 'course',
#  706: 'bad',
#  707: 'fall',
#  708: 'Group',
#  709: 'October',
#  710: 'jobs',
#  711: 'list',
#  712: 'let',
#  713: 'however',
#  714: 'chief',
#  715: 'summer',
#  716: 'programs',
#  717: 'According',
#  718: 'revenue',
#  719: 'Our',
#  720: 'rose',
#  721: 'previous',
#  722: 'TV',
#  723: 'football',
#  724: 'biggest',
#  725: 'employees',
#  726: 'changes',
#  727: 'residents',
#  728: 'means',
#  729: 'agreement',
#  730: 'includes',
#  731: 'post',
#  732: 'Canada',
#  733: 'probably',
#  734: 'related',
#  735: 'training',
#  736: 'allowed',
#  737: 'class',
#  738: 'bit',
#  739: 'video',
#  740: 'Michael',
#  741: 'An',
#  742: 'sent',
#  743: 'education',
#  744: 'states',
#  745: 'straight',
#  746: 'love',
#  747: 'beat',
#  748: 'hold',
#  749: 'turn',
#  750: 'finished',
#  751: 'network',
#  752: 'Smith',
#  753: 'buy',
#  754: 'foreign',
#  755: 'especially',
#  756: 'groups',
#  757: 'wants',
#  758: 'title',
#  759: 'included',
#  760: 'turned',
#  761: 'bank',
#  762: 'Florida',
#  763: 'efforts',
#  764: 'personal',
#  765: 'businesses',
#  766: 'August',
#  767: 'California',
#  768: 'situation',
#  769: 'district',
#  770: 'allow',
#  771: 'helped',
#  772: 'body',
#  773: 'nothing',
#  774: 'soon',
#  775: 'safety',
#  776: 'officer',
#  777: 'cents',
#  778: 'Europe',
#  779: 'St.',
#  780: 'additional',
#  781: 'spokesman',
#  782: 'February',
#  783: 'wife',
#  784: 'showed',
#  785: 'leave',
#  786: 'investors',
#  787: 'parents',
#  788: 'medical',
#  789: 'spending',
#  790: 'non',
#  791: 'London',
#  792: 'Council',
#  793: 'matter',
#  794: 'spent',
#  795: 'child',
#  796: 'World',
#  797: 'effort',
#  798: 'opening',
#  799: 'either',
#  800: 'range',
#  801: 'question',
#  802: 'European',
#  803: 'goals',
#  804: 'administration',
#  805: 'friends',
#  806: 'himself',
#  807: 'shows',
#  808: 'difficult',
#  809: 'kids',
#  810: 'paid',
#  811: 'create',
#  812: 'cash',
#  813: 'age',
#  814: 'league',
#  815: 'form',
#  816: 'impact',
#  817: 'drive',
#  818: 'someone',
#  819: 'became',
#  820: 'stay',
#  821: 'fight',
#  822: 'significant',
#  823: 'firm',
#  824: 'Senate',
#  825: 'hospital',
#  826: 'charged',
#  827: 'operating',
#  828: 'main',
#  829: 'book',
#  830: 'success',
#  831: 'son',
#  832: 'trading',
#  833: '###-####',
#  834: 'focus',
#  835: 'room',
#  836: 'continued',
#  837: 'Congress',
#  838: 'everything',
#  839: 'Park',
#  840: 'agency',
#  841: 'brought',
#  842: 'talk',
#  843: 'break',
#  844: 'air',
#  845: 'software',
#  846: 'decided',
#  847: 'Do',
#  848: 'ready',
#  849: 'arrested',
#  850: 'track',
#  851: 'provides',
#  852: 'mother',
#  853: 'base',
#  854: 'trial',
#  855: 'phone',
#  856: 'My',
#  857: 'build',
#  858: 'conditions',
#  859: 'rest',
#  860: 'Johnson',
#  861: 'terms',
#  862: 'expect',
#  863: 'England',
#  864: 'Israel',
#  865: 'despite',
#  866: 'closed',
#  867: 'starting',
#  868: 'provided',
#  869: 'pressure',
#  870: 'lives',
#  871: 'step',
#  872: 'remain',
#  873: 'similar',
#  874: 'charge',
#  875: 'date',
#  876: 'whole',
#  877: 'land',
#  878: 'growing',
#  879: 'James',
#  880: 'Internet',
#  881: 'projects',
#  882: 'British',
#  883: 'cases',
#  884: 'ground',
#  885: 'legal',
#  886: 'International',
#  887: 'agreed',
#  888: 'tell',
#  889: 'test',
#  890: 'everyone',
#  891: 'pretty',
#  892: 'authorities',
#  893: 'Two',
#  894: 'above',
#  895: 'moved',
#  896: 'profit',
#  897: 'throughout',
#  898: 'inside',
#  899: 'ability',
#  900: 'overall',
#  901: 'pass',
#  902: 'officers',
#  903: 'rather',
#  904: 'Australia',
#  905: 'actually',
#  906: 'county',
#  907: 'amount',
#  908: 'scheduled',
#  909: 'themselves',
#  910: 'organization',
#  911: 'giving',
#  912: 'credit',
#  913: 'father',
#  914: 'drug',
#  915: 'investigation',
#  916: 'families',
#  917: 'Republican',
#  918: 'funds',
#  919: 'patients',
#  920: 'takes',
#  921: 'systems',
#  922: 'Japan',
#  923: 'complete',
#  924: 'sold',
#  925: 'practice',
#  926: 'calls',
#  927: '•',
#  928: 'UK',
#  929: 'force',
#  930: 'student',
#  931: 'idea',
#  932: 'reached',
#  933: 'reason',
#  934: 'levels',
#  935: 'space',
#  936: 'competition',
#  937: 'forces',
#  938: 'sector',
#  939: 'Last',
#  940: 'tried',
#  941: 'common',
#  942: 'homes',
#  943: 'stage',
#  944: 'department',
#  945: 'named',
#  946: 'earnings',
#  947: 'offers',
#  948: 'star',
#  949: 'certain',
#  950: 'double',
#  951: 'longer',
#  952: 'followed',
#  953: 'cause',
#  954: 'Association',
#  955: 'signed',
#  956: 'committee',
#  957: 'hour',
#  958: 'college',
#  959: 'Pakistan',
#  960: 'users',
#  961: 'Iran',
#  962: 'sign',
#  963: 'living',
#  964: 'failed',
#  965: 'reach',
#  966: 'quickly',
#  967: 'receive',
#  968: 'debt',
#  969: 'sale',
#  970: 'Board',
#  971: 'Americans',
#  972: 'Road',
#  973: 'Brown',
#  974: 'insurance',
#  975: '##:##',
#  976: 'anyone',
#  977: 'tournament',
#  978: 'More',
#  979: 'gas',
#  980: 'talks',
#  981: 'serious',
#  982: 'required',
#  983: 'sell',
#  984: 'construction',
#  985: 'evidence',
#  986: 'remains',
#  987: 'black',
#  988: 'below',
#  989: 'improve',
#  990: 'crisis',
#  991: 'address',
#  992: 'questions',
#  993: 'easy',
#  994: 'begin',
#  995: 'view',
#  996: 'School',
#  997: 'heard',
#  998: 'executive',
#  999: 'raised',
#  ...}

# %%
word2index
# Out:
# {'</s>': 0,
#  'in': 1,
#  'for': 2,
#  'that': 3,
#  'is': 4,
#  'on': 5,
#  '##': 6,
#  'The': 7,
#  'with': 8,
#  'said': 9,
#  'was': 10,
#  'the': 11,
#  'at': 12,
#  'not': 13,
#  'as': 14,
#  'it': 15,
#  'be': 16,
#  'from': 17,
#  'by': 18,
#  'are': 19,
#  'I': 20,
#  'have': 21,
#  'he': 22,
#  'will': 23,
#  'has': 24,
#  '####': 25,
#  'his': 26,
#  'an': 27,
#  'this': 28,
#  'or': 29,
#  'their': 30,
#  'who': 31,
#  'they': 32,
#  'but': 33,
#  '$': 34,
#  'had': 35,
#  'year': 36,
#  'were': 37,
#  'we': 38,
#  'more': 39,
#  '###': 40,
#  'up': 41,
#  'been': 42,
#  'you': 43,
#  'its': 44,
#  'one': 45,
#  'about': 46,
#  'would': 47,
#  'which': 48,
#  'out': 49,
#  'can': 50,
#  'It': 51,
#  'all': 52,
#  'also': 53,
#  'two': 54,
#  'after': 55,
#  'first': 56,
#  'He': 57,
#  'do': 58,
#  'time': 59,
#  'than': 60,
#  'when': 61,
#  'We': 62,
#  'over': 63,
#  'last': 64,
#  'new': 65,
#  'other': 66,
#  'her': 67,
#  'people': 68,
#  'into': 69,
#  'In': 70,
#  'our': 71,
#  'there': 72,
#  'A': 73,
#  'she': 74,
#  'could': 75,
#  'just': 76,
#  'years': 77,
#  'some': 78,
#  'U.S.': 79,
#  'three': 80,
#  'million': 81,
#  'them': 82,
#  'what': 83,
#  'But': 84,
#  'so': 85,
#  'no': 86,
#  'like': 87,
#  'if': 88,
#  'only': 89,
#  'percent': 90,
#  'get': 91,
#  'did': 92,
#  'him': 93,
#  'game': 94,
#  'back': 95,
#  'because': 96,
#  'now': 97,
#  '#.#': 98,
#  'before': 99,
#  'company': 100,
#  'any': 101,
#  'team': 102,
#  'against': 103,
#  'off': 104,
#  'This': 105,
#  'most': 106,
#  'made': 107,
#  'through': 108,
#  'make': 109,
#  'second': 110,
#  'state': 111,
#  'well': 112,
#  'day': 113,
#  'season': 114,
#  'says': 115,
#  'week': 116,
#  'where': 117,
#  'while': 118,
#  'down': 119,
#  'being': 120,
#  'government': 121,
#  'your': 122,
#  '#-#': 123,
#  'home': 124,
#  'going': 125,
#  'my': 126,
#  'good': 127,
#  'They': 128,
#  "'re": 129,
#  'should': 130,
#  'many': 131,
#  'way': 132,
#  'those': 133,
#  'four': 134,
#  'during': 135,
#  'such': 136,
#  'may': 137,
#  'very': 138,
#  'how': 139,
#  'since': 140,
#  'work': 141,
#  'take': 142,
#  'including': 143,
#  'high': 144,
#  'then': 145,
#  '%': 146,
#  'next': 147,
#  '#,###': 148,
#  'By': 149,
#  'much': 150,
#  'still': 151,
#  'go': 152,
#  'think': 153,
#  'old': 154,
#  'even': 155,
#  '#.##': 156,
#  'world': 157,
#  'see': 158,
#  'say': 159,
#  'business': 160,
#  'five': 161,
#  'told': 162,
#  'under': 163,
#  'us': 164,
#  '1': 165,
#  'these': 166,
#  'If': 167,
#  'right': 168,
#  'And': 169,
#  'me': 170,
#  'between': 171,
#  'play': 172,
#  'help': 173,
#  '##,###': 174,
#  'market': 175,
#  'That': 176,
#  'know': 177,
#  'end': 178,
#  'AP': 179,
#  'long': 180,
#  'information': 181,
#  'points': 182,
#  'does': 183,
#  'both': 184,
#  'There': 185,
#  'part': 186,
#  'around': 187,
#  'police': 188,
#  'want': 189,
#  "'ve": 190,
#  'based': 191,
#  'For': 192,
#  'got': 193,
#  'third': 194,
#  'school': 195,
#  'left': 196,
#  'another': 197,
#  'country': 198,
#  'need': 199,
#  '2': 200,
#  'best': 201,
#  'win': 202,
#  'quarter': 203,
#  'use': 204,
#  'today': 205,
#  '##.#': 206,
#  'same': 207,
#  'public': 208,
#  'run': 209,
#  'Friday': 210,
#  'set': 211,
#  'month': 212,
#  'top': 213,
#  'billion': 214,
#  'Tuesday': 215,
#  'come': 216,
#  'Monday': 217,
#  'She': 218,
#  'city': 219,
#  'place': 220,
#  'night': 221,
#  'six': 222,
#  'each': 223,
#  'Thursday': 224,
#  '###,###': 225,
#  'Wednesday': 226,
#  'here': 227,
#  'You': 228,
#  'group': 229,
#  'really': 230,
#  'found': 231,
#  'As': 232,
#  'used': 233,
#  '3': 234,
#  'lot': 235,
#  "'m": 236,
#  'money': 237,
#  'put': 238,
#  'games': 239,
#  'support': 240,
#  'program': 241,
#  'half': 242,
#  'report': 243,
#  'family': 244,
#  'months': 245,
#  'number': 246,
#  'officials': 247,
#  'am': 248,
#  'former': 249,
#  'own': 250,
#  'man': 251,
#  'Saturday': 252,
#  'too': 253,
#  'better': 254,
#  'days': 255,
#  'came': 256,
#  'lead': 257,
#  'life': 258,
#  'American': 259,
#  '##-##': 260,
#  'show': 261,
#  'past': 262,
#  'took': 263,
#  'added': 264,
#  'expected': 265,
#  'called': 266,
#  'great': 267,
#  'State': 268,
#  'services': 269,
#  'children': 270,
#  'hit': 271,
#  'area': 272,
#  'system': 273,
#  'every': 274,
#  'pm': 275,
#  'big': 276,
#  'service': 277,
#  'few': 278,
#  'per': 279,
#  'members': 280,
#  'Sunday': 281,
#  'early': 282,
#  'point': 283,
#  'start': 284,
#  'companies': 285,
#  'little': 286,
#  '&': 287,
#  'case': 288,
#  'ago': 289,
#  'local': 290,
#  'according': 291,
#  'never': 292,
#  '5': 293,
#  'without': 294,
#  'sales': 295,
#  'until': 296,
#  'went': 297,
#  'players': 298,
#  '##th': 299,
#  'New_York': 300,
#  'won': 301,
#  'financial': 302,
#  'news': 303,
#  '4': 304,
#  'When': 305,
#  'share': 306,
#  'several': 307,
#  'free': 308,
#  'away': 309,
#  '##.##': 310,
#  'already': 311,
#  'On': 312,
#  'industry': 313,
#  "'ll": 314,
#  'call': 315,
#  'With': 316,
#  'students': 317,
#  'line': 318,
#  'available': 319,
#  'County': 320,
#  'making': 321,
#  'held': 322,
#  'final': 323,
#  '#:##': 324,
#  'power': 325,
#  'plan': 326,
#  'might': 327,
#  'least': 328,
#  'look': 329,
#  'forward': 330,
#  'give': 331,
#  'At': 332,
#  'again': 333,
#  'later': 334,
#  'full': 335,
#  'must': 336,
#  'things': 337,
#  'major': 338,
#  'community': 339,
#  'announced': 340,
#  'open': 341,
#  'record': 342,
#  'reported': 343,
#  'court': 344,
#  'working': 345,
#  'able': 346,
#  'something': 347,
#  'president': 348,
#  'meeting': 349,
#  'keep': 350,
#  'March': 351,
#  'future': 352,
#  'far': 353,
#  'deal': 354,
#  'City': 355,
#  'May': 356,
#  'development': 357,
#  'University': 358,
#  'find': 359,
#  'times': 360,
#  'After': 361,
#  'office': 362,
#  'led': 363,
#  'among': 364,
#  'June': 365,
#  'increase': 366,
#  'China': 367,
#  'John': 368,
#  'whether': 369,
#  'cost': 370,
#  'security': 371,
#  'job': 372,
#  'less': 373,
#  'head': 374,
#  'seven': 375,
#  'growth': 376,
#  'lost': 377,
#  'pay': 378,
#  'looking': 379,
#  'provide': 380,
#  '6': 381,
#  'To': 382,
#  'plans': 383,
#  'products': 384,
#  'car': 385,
#  'recent': 386,
#  'hard': 387,
#  'always': 388,
#  'include': 389,
#  'women': 390,
#  'across': 391,
#  'tax': 392,
#  'water': 393,
#  'April': 394,
#  'continue': 395,
#  'important': 396,
#  'different': 397,
#  'close': 398,
#  '7': 399,
#  'One': 400,
#  'late': 401,
#  'decision': 402,
#  'current': 403,
#  'law': 404,
#  'within': 405,
#  'along': 406,
#  'played': 407,
#  'move': 408,
#  'United_States': 409,
#  'enough': 410,
#  'become': 411,
#  'side': 412,
#  'national': 413,
#  'Inc.': 414,
#  'results': 415,
#  'level': 416,
#  'loss': 417,
#  'economic': 418,
#  'coach': 419,
#  'near': 420,
#  'getting': 421,
#  'price': 422,
#  'Department': 423,
#  'event': 424,
#  'fourth': 425,
#  'change': 426,
#  'All': 427,
#  'small': 428,
#  'board': 429,
#  'National': 430,
#  'So': 431,
#  'goal': 432,
#  'taken': 433,
#  'field': 434,
#  'prices': 435,
#  'weeks': 436,
#  'men': 437,
#  'asked': 438,
#  'eight': 439,
#  'data': 440,
#  'shot': 441,
#  'New': 442,
#  'started': 443,
#  'July': 444,
#  'director': 445,
#  'President': 446,
#  'party': 447,
#  'federal': 448,
#  'done': 449,
#  'political': 450,
#  'minutes': 451,
#  'taking': 452,
#  'Company': 453,
#  'technology': 454,
#  'project': 455,
#  'center': 456,
#  'leading': 457,
#  'issue': 458,
#  'though': 459,
#  'having': 460,
#  'period': 461,
#  'likely': 462,
#  'scored': 463,
#  '8': 464,
#  'strong': 465,
#  'series': 466,
#  'military': 467,
#  'seen': 468,
#  'trying': 469,
#  'What': 470,
#  'coming': 471,
#  'process': 472,
#  'building': 473,
#  'behind': 474,
#  'performance': 475,
#  'management': 476,
#  'Iraq': 477,
#  'saying': 478,
#  'earlier': 479,
#  'believe': 480,
#  'oil': 481,
#  'given': 482,
#  'Police': 483,
#  'customers': 484,
#  'due': 485,
#  'following': 486,
#  'term': 487,
#  'others': 488,
#  'statement': 489,
#  'international': 490,
#  'economy': 491,
#  'health': 492,
#  'thing': 493,
#  'Obama': 494,
#  'return': 495,
#  'killed': 496,
#  'Washington': 497,
#  'further': 498,
#  'However': 499,
#  'doing': 500,
#  'face': 501,
#  'low': 502,
#  'higher': 503,
#  'site': 504,
#  'once': 505,
#  'yet': 506,
#  'hours': 507,
#  'America': 508,
#  'control': 509,
#  'received': 510,
#  'rate': 511,
#  'career': 512,
#  'Bush': 513,
#  'teams': 514,
#  'known': 515,
#  'offer': 516,
#  'race': 517,
#  'ever': 518,
#  'experience': 519,
#  'playing': 520,
#  'name': 521,
#  'possible': 522,
#  'countries': 523,
#  'Mr.': 524,
#  'average': 525,
#  'together': 526,
#  'using': 527,
#  '9': 528,
#  'cut': 529,
#  'While': 530,
#  'total': 531,
#  'round': 532,
#  'young': 533,
#  'nearly': 534,
#  'shares': 535,
#  'member': 536,
#  'campaign': 537,
#  'media': 538,
#  'needs': 539,
#  'why': 540,
#  'house': 541,
#  'issues': 542,
#  'costs': 543,
#  'fire': 544,
#  '##-#': 545,
#  'victory': 546,
#  'player': 547,
#  'began': 548,
#  'sure': 549,
#  'story': 550,
#  'per_cent': 551,
#  'North': 552,
#  'His': 553,
#  'staff': 554,
#  'order': 555,
#  'war': 556,
#  'large': 557,
#  'interest': 558,
#  'stock': 559,
#  'food': 560,
#  'research': 561,
#  'key': 562,
#  'India': 563,
#  'South': 564,
#  'morning': 565,
#  'conference': 566,
#  'senior': 567,
#  'global': 568,
#  'Center': 569,
#  'death': 570,
#  'person': 571,
#  'thought': 572,
#  'gave': 573,
#  'feel': 574,
#  'energy': 575,
#  'history': 576,
#  'recently': 577,
#  'largest': 578,
#  'No.': 579,
#  'general': 580,
#  'official': 581,
#  'released': 582,
#  'wanted': 583,
#  'meet': 584,
#  'short': 585,
#  'outside': 586,
#  'running': 587,
#  'live': 588,
#  'ball': 589,
#  'online': 590,
#  'real': 591,
#  'position': 592,
#  'fact': 593,
#  'fell': 594,
#  'nine': 595,
#  'December': 596,
#  'front': 597,
#  'action': 598,
#  'defense': 599,
#  'problem': 600,
#  'problems': 601,
#  'Mr': 602,
#  'nation': 603,
#  'needed': 604,
#  'special': 605,
#  'January': 606,
#  'almost': 607,
#  'chance': 608,
#  "'d": 609,
#  'result': 610,
#  'West': 611,
#  'September': 612,
#  'reports': 613,
#  'leader': 614,
#  'investment': 615,
#  'yesterday': 616,
#  'Some': 617,
#  'leaders': 618,
#  'ahead': 619,
#  'production': 620,
#  'comes': 621,
#  'No': 622,
#  'runs': 623,
#  'match': 624,
#  'role': 625,
#  'kind': 626,
#  'try': 627,
#  'ended': 628,
#  'risk': 629,
#  'areas': 630,
#  'election': 631,
#  'workers': 632,
#  'visit': 633,
#  'bring': 634,
#  'road': 635,
#  'music': 636,
#  'study': 637,
#  'makes': 638,
#  'often': 639,
#  'release': 640,
#  'woman': 641,
#  'vote': 642,
#  'care': 643,
#  'town': 644,
#  'clear': 645,
#  'comment': 646,
#  'budget': 647,
#  'potential': 648,
#  'single': 649,
#  'markets': 650,
#  'policy': 651,
#  'capital': 652,
#  'saw': 653,
#  'access': 654,
#  'weekend': 655,
#  'operations': 656,
#  'whose': 657,
#  'net': 658,
#  'House': 659,
#  'hand': 660,
#  'increased': 661,
#  'charges': 662,
#  'winning': 663,
#  'trade': 664,
#  'These': 665,
#  'income': 666,
#  'value': 667,
#  'involved': 668,
#  'Bank': 669,
#  'November': 670,
#  'bill': 671,
#  'compared': 672,
#  'anything': 673,
#  'manager': 674,
#  'Texas': 675,
#  'property': 676,
#  'stop': 677,
#  'annual': 678,
#  'private': 679,
#  'contract': 680,
#  'died': 681,
#  'Now': 682,
#  'hope': 683,
#  'product': 684,
#  'fans': 685,
#  'lower': 686,
#  'demand': 687,
#  'News': 688,
#  'David': 689,
#  'club': 690,
#  'comments': 691,
#  'film': 692,
#  'yards': 693,
#  'quality': 694,
#  'currently': 695,
#  'events': 696,
#  'addition': 697,
#  'couple': 698,
#  'schools': 699,
#  'attack': 700,
#  'region': 701,
#  'latest': 702,
#  'opportunity': 703,
#  'worked': 704,
#  'course': 705,
#  'bad': 706,
#  'fall': 707,
#  'Group': 708,
#  'October': 709,
#  'jobs': 710,
#  'list': 711,
#  'let': 712,
#  'however': 713,
#  'chief': 714,
#  'summer': 715,
#  'programs': 716,
#  'According': 717,
#  'revenue': 718,
#  'Our': 719,
#  'rose': 720,
#  'previous': 721,
#  'TV': 722,
#  'football': 723,
#  'biggest': 724,
#  'employees': 725,
#  'changes': 726,
#  'residents': 727,
#  'means': 728,
#  'agreement': 729,
#  'includes': 730,
#  'post': 731,
#  'Canada': 732,
#  'probably': 733,
#  'related': 734,
#  'training': 735,
#  'allowed': 736,
#  'class': 737,
#  'bit': 738,
#  'video': 739,
#  'Michael': 740,
#  'An': 741,
#  'sent': 742,
#  'education': 743,
#  'states': 744,
#  'straight': 745,
#  'love': 746,
#  'beat': 747,
#  'hold': 748,
#  'turn': 749,
#  'finished': 750,
#  'network': 751,
#  'Smith': 752,
#  'buy': 753,
#  'foreign': 754,
#  'especially': 755,
#  'groups': 756,
#  'wants': 757,
#  'title': 758,
#  'included': 759,
#  'turned': 760,
#  'bank': 761,
#  'Florida': 762,
#  'efforts': 763,
#  'personal': 764,
#  'businesses': 765,
#  'August': 766,
#  'California': 767,
#  'situation': 768,
#  'district': 769,
#  'allow': 770,
#  'helped': 771,
#  'body': 772,
#  'nothing': 773,
#  'soon': 774,
#  'safety': 775,
#  'officer': 776,
#  'cents': 777,
#  'Europe': 778,
#  'St.': 779,
#  'additional': 780,
#  'spokesman': 781,
#  'February': 782,
#  'wife': 783,
#  'showed': 784,
#  'leave': 785,
#  'investors': 786,
#  'parents': 787,
#  'medical': 788,
#  'spending': 789,
#  'non': 790,
#  'London': 791,
#  'Council': 792,
#  'matter': 793,
#  'spent': 794,
#  'child': 795,
#  'World': 796,
#  'effort': 797,
#  'opening': 798,
#  'either': 799,
#  'range': 800,
#  'question': 801,
#  'European': 802,
#  'goals': 803,
#  'administration': 804,
#  'friends': 805,
#  'himself': 806,
#  'shows': 807,
#  'difficult': 808,
#  'kids': 809,
#  'paid': 810,
#  'create': 811,
#  'cash': 812,
#  'age': 813,
#  'league': 814,
#  'form': 815,
#  'impact': 816,
#  'drive': 817,
#  'someone': 818,
#  'became': 819,
#  'stay': 820,
#  'fight': 821,
#  'significant': 822,
#  'firm': 823,
#  'Senate': 824,
#  'hospital': 825,
#  'charged': 826,
#  'operating': 827,
#  'main': 828,
#  'book': 829,
#  'success': 830,
#  'son': 831,
#  'trading': 832,
#  '###-####': 833,
#  'focus': 834,
#  'room': 835,
#  'continued': 836,
#  'Congress': 837,
#  'everything': 838,
#  'Park': 839,
#  'agency': 840,
#  'brought': 841,
#  'talk': 842,
#  'break': 843,
#  'air': 844,
#  'software': 845,
#  'decided': 846,
#  'Do': 847,
#  'ready': 848,
#  'arrested': 849,
#  'track': 850,
#  'provides': 851,
#  'mother': 852,
#  'base': 853,
#  'trial': 854,
#  'phone': 855,
#  'My': 856,
#  'build': 857,
#  'conditions': 858,
#  'rest': 859,
#  'Johnson': 860,
#  'terms': 861,
#  'expect': 862,
#  'England': 863,
#  'Israel': 864,
#  'despite': 865,
#  'closed': 866,
#  'starting': 867,
#  'provided': 868,
#  'pressure': 869,
#  'lives': 870,
#  'step': 871,
#  'remain': 872,
#  'similar': 873,
#  'charge': 874,
#  'date': 875,
#  'whole': 876,
#  'land': 877,
#  'growing': 878,
#  'James': 879,
#  'Internet': 880,
#  'projects': 881,
#  'British': 882,
#  'cases': 883,
#  'ground': 884,
#  'legal': 885,
#  'International': 886,
#  'agreed': 887,
#  'tell': 888,
#  'test': 889,
#  'everyone': 890,
#  'pretty': 891,
#  'authorities': 892,
#  'Two': 893,
#  'above': 894,
#  'moved': 895,
#  'profit': 896,
#  'throughout': 897,
#  'inside': 898,
#  'ability': 899,
#  'overall': 900,
#  'pass': 901,
#  'officers': 902,
#  'rather': 903,
#  'Australia': 904,
#  'actually': 905,
#  'county': 906,
#  'amount': 907,
#  'scheduled': 908,
#  'themselves': 909,
#  'organization': 910,
#  'giving': 911,
#  'credit': 912,
#  'father': 913,
#  'drug': 914,
#  'investigation': 915,
#  'families': 916,
#  'Republican': 917,
#  'funds': 918,
#  'patients': 919,
#  'takes': 920,
#  'systems': 921,
#  'Japan': 922,
#  'complete': 923,
#  'sold': 924,
#  'practice': 925,
#  'calls': 926,
#  '•': 927,
#  'UK': 928,
#  'force': 929,
#  'student': 930,
#  'idea': 931,
#  'reached': 932,
#  'reason': 933,
#  'levels': 934,
#  'space': 935,
#  'competition': 936,
#  'forces': 937,
#  'sector': 938,
#  'Last': 939,
#  'tried': 940,
#  'common': 941,
#  'homes': 942,
#  'stage': 943,
#  'department': 944,
#  'named': 945,
#  'earnings': 946,
#  'offers': 947,
#  'star': 948,
#  'certain': 949,
#  'double': 950,
#  'longer': 951,
#  'followed': 952,
#  'cause': 953,
#  'Association': 954,
#  'signed': 955,
#  'committee': 956,
#  'hour': 957,
#  'college': 958,
#  'Pakistan': 959,
#  'users': 960,
#  'Iran': 961,
#  'sign': 962,
#  'living': 963,
#  'failed': 964,
#  'reach': 965,
#  'quickly': 966,
#  'receive': 967,
#  'debt': 968,
#  'sale': 969,
#  'Board': 970,
#  'Americans': 971,
#  'Road': 972,
#  'Brown': 973,
#  'insurance': 974,
#  '##:##': 975,
#  'anyone': 976,
#  'tournament': 977,
#  'More': 978,
#  'gas': 979,
#  'talks': 980,
#  'serious': 981,
#  'required': 982,
#  'sell': 983,
#  'construction': 984,
#  'evidence': 985,
#  'remains': 986,
#  'black': 987,
#  'below': 988,
#  'improve': 989,
#  'crisis': 990,
#  'address': 991,
#  'questions': 992,
#  'easy': 993,
#  'begin': 994,
#  'view': 995,
#  'School': 996,
#  'heard': 997,
#  'executive': 998,
#  'raised': 999,
#  ...}

# %%
feature_size = 300    # Word vector dimensionality  
w2v_feature_array = averaged_word_vectorizer(corpus=tokenized_corpus, model=word2vec,
                                             num_features=feature_size)# get document level embeddings
sentence_with_embedding = pd.DataFrame(w2v_feature_array)
sentence_with_embedding
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.023214 -0.006714  0.064401  0.073133 -0.059627 -0.043599  0.047528
# 1    0.051753  0.039621  0.025340  0.069039 -0.053083 -0.037171  0.024907
# 2    0.014664  0.038765  0.034824  0.125324 -0.067249 -0.029823  0.033368
# 3   -0.010701  0.030304  0.054109  0.081180 -0.077948 -0.004409  0.034984
# 4    0.027871  0.032892  0.038572  0.074852 -0.080632 -0.027350  0.046168
# ..        ...       ...       ...       ...       ...       ...       ...
# 838  0.022604  0.017110  0.014440  0.104725 -0.055223 -0.009985  0.053157
# 839  0.039272 -0.068778  0.065273  0.137626 -0.092390 -0.018851  0.042737
# 840  0.036872  0.064374  0.028909  0.112728 -0.091183  0.002245  0.076359
# 841  0.042835  0.018250  0.036113  0.074287 -0.080746 -0.037904  0.002342
# 842 -0.027910  0.027969  0.081997  0.035330 -0.090340 -0.035995  0.017999
#
#           7         8         9    ...       290       291       292  \
# 0   -0.053001  0.051799  0.095397  ... -0.117057  0.020943 -0.068164
# 1   -0.084676  0.065206  0.068440  ... -0.090238  0.014225 -0.054791
# 2   -0.062650  0.030625  0.073065  ... -0.083568  0.030815 -0.076470
# 3   -0.051645  0.074295  0.064262  ... -0.082243  0.000819 -0.045814
# 4   -0.059409  0.061953  0.061391  ... -0.122690  0.025577 -0.067139
# ..        ...       ...       ...  ...       ...       ...       ...
# 838 -0.073784  0.061795  0.053846  ... -0.078055  0.037884 -0.063528
# 839 -0.066232 -0.004551  0.055965  ... -0.086600  0.096034 -0.070326
# 840 -0.025385  0.109442  0.062135  ... -0.045421  0.020182 -0.101699
# 841 -0.056982  0.043012  0.045480  ... -0.105935  0.015379 -0.091042
# 842 -0.062508  0.074265  0.063141  ... -0.078018 -0.001960 -0.058113
#
#           293       294       295       296       297       298       299
# 0    0.029496  0.024905  0.031825 -0.035953 -0.063669  0.013590 -0.054310
# 1    0.063705 -0.001520  0.020743  0.022604 -0.035064  0.050186 -0.041322
# 2    0.023152 -0.022078 -0.013197 -0.015569 -0.051680  0.062030 -0.064512
# 3    0.025555  0.020977  0.036075 -0.052010 -0.056929  0.066396 -0.048546
# 4    0.008679 -0.026923  0.009250 -0.004940 -0.050601  0.053983 -0.027275
# ..        ...       ...       ...       ...       ...       ...       ...
# 838  0.034226 -0.000171 -0.013184 -0.003839 -0.045739  0.031994 -0.040155
# 839  0.035749  0.044528 -0.034616 -0.047435 -0.126866  0.014714 -0.035505
# 840  0.032830 -0.040882  0.062439 -0.043146 -0.021549  0.083983 -0.038553
# 841  0.045043  0.038266  0.003242 -0.003562 -0.025918  0.032084 -0.038244
# 842  0.008202 -0.049850 -0.000989  0.002713 -0.012390  0.023560 -0.110126
#
# [843 rows x 300 columns]

# %%
model = fit_model(sentence_with_embedding, true_k)
terms_per_cluster(model, index2word)
# Out:
# Top terms per cluster:
# Cluster 0:
#  expected
#  her
#  there
#  U.S.
#  like
#  police
#  put
#  just
#  took
#  come
#  area
#  years
#  that
#  added
#  while
#
#
# Cluster 1:
#  against
#  added
#  business
#  top
#  They
#  Tuesday
#  team
#  are
#  took
#  early
#  'm
#  been
#  under
#  place
#  #-#
#
#
# Cluster 2:
#  season
#  against
#  put
#  expected
#  Tuesday
#  how
#  off
#  too
#  Monday
#  team
#  They
#  early
#  five
#  It
#  been
#
#
# Cluster 3:
#  expected
#  put
#  there
#  her
#  police
#  added
#  took
#  U.S.
#  top
#  like
#  season
#  how
#  too
#  They
#  while

# %%
check_result(data, true_k)
# Out:
# t0 and 0 : 0.34231378763866877
# t1 and 0 : 0.24088748019017434
# t2 and 0 : 0.2202852614896989
# t3 and 0 : 0.196513470681458
# t0 and 1 : 0.0
# t1 and 1 : 0.0
# t2 and 1 : 0.0
# t3 and 1 : 1.0
# t0 and 2 : 0.0
# t1 and 2 : 0.375
# t2 and 2 : 0.5
# t3 and 2 : 0.125
# t0 and 3 : 0.38613861386138615
# t1 and 3 : 0.18316831683168316
# t2 and 3 : 0.18811881188118812
# t3 and 3 : 0.24257425742574257

# %%
dic = {
    0:'t0' ,
    1:'t3' ,
    2:'t2' ,
    3:'t1' 
}

# %%
data.labels = data.labels.replace(dic)

# %%
data
# Out:
#                                                   text topic labels
# 0    block that bounders and st where 3 storeys are...    t0     t0
# 1    rapid development of with large apartment buil...    t0     t0
# 2    i think large apartment developments should be...    t0     t0
# 3    i believe that allowing 5 storey unit developm...    t0     t0
# 4    our logic is that prehouses with gardens is th...    t0     t0
# ..                                                 ...   ...    ...
# 838  to need to be the greenspace not more building...    t3     t0
# 839          you not have development near or cb park     t3     t2
# 840  trees need better care as many die as not wate...    t3     t0
# 841  the number of young families and couples movin...    t3     t0
# 842  that and prioritise actions contained within t...    t3     t0
#
# [843 rows x 3 columns]

# %%
len(data[data.labels == data.topic])/len(data)
# Out:
# 0.30723606168446027

# %%
test_text = """
i think large apartment developments should be built along major road e g street street etc i do not agree with building them along areas with large parks as the people that live here enjoy the being able to look out their windows and see the park this is why they live here
"""
test_sent(test_text, model, dic, word2vec, feature_size)
# Out:
# 't0'

# %%
df_test = pd.read_excel('File_Test1.xlsx')
df_test.head()
# Out:
#    ID number                                           Comments
# 0          1  its heading in the right direction. completely...
# 1          2  for the environment. extremely small residenti...
# 2          3  to preserving the bushland, commitment to ensu...
# 3          4  N/A. bus service for dont want town houses at ...
# 4          5  there is a strategy, and subsequently a plan.....

# %%
# Predicting topics for each sentences in the test dataset
for index, row in df_test.iterrows():
    df_test.at[index, 'label'] = test_sent(row.Comments, model, dic, word2vec, feature_size)

# %%
df_test.label.value_counts()
# Out:
# t0    116
# t1     60
# Name: label, dtype: int64

# %%
df_test.head()
# Out:
#    ID number                                           Comments label
# 0          1  its heading in the right direction. completely...    t0
# 1          2  for the environment. extremely small residenti...    t0
# 2          3  to preserving the bushland, commitment to ensu...    t1
# 3          4  N/A. bus service for dont want town houses at ...    t0
# 4          5  there is a strategy, and subsequently a plan.....    t0
