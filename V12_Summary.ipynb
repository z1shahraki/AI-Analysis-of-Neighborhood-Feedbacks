# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import torch
import json 
from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config
import chardet
import numpy as np

# %%
model = T5ForConditionalGeneration.from_pretrained('t5-small')
tokenizer = T5Tokenizer.from_pretrained('t5-small')
device = torch.device('cpu')

# %%
def read_mycsv(path):
    with open(path, 'rb') as f:
        result = chardet.detect(f.read())
    return pd.read_csv(path, encoding=result['encoding'])

# %%
text = pd.read_excel('CPED - NPUR.xlsx')
text.head(20)
# Out:
#                                         Original text  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   "believe there are a number of issues that nee...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10   a resident of and a frequent traveller on the...
# 11  I have just built a new home in Road, Kedron. ...
# 12  I would like to express my concerns with the p...
# 13                                                NaN
# 14  watched my son who lives at fill out the onlin...
# 15  its heading in the right direction. completely...
# 16                                                NaN
# 17  I am amazed and disappointed that after all th...
# 18                                                NaN
# 19                                                NaN
#
#                                        Segmented text  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   1) mechanisms\n• is surrounded by high levels ...
# 6   2) • is identified within Footprint, although ...
# 7   3) and • nature conservation values bordering ...
# 8   6) and • area is identified as having high to ...
# 9   4) • and improve the main waterway corridor th...
# 10   a resident of and a frequent traveller on the...
# 11  I have just built a new home in Road, Kedron. ...
# 12  I would like to express my concerns with the p...
# 13  Road is already chaotic for us at the moment a...
# 14  watched my son who lives at fill out the onlin...
# 15  its heading in the right direction. completely...
# 16  lacks infrastructure in these areas. would be ...
# 17  I am amazed and disappointed that after all th...
# 18  is a copy of a statement I prepared in for par...
# 19  UPPER KEDRON DEVELOPMENT a resident of for 15 ...
#
#    Example structure of outputs of analysis         Unnamed: 3  \
# 0                                       NaN                NaN
# 1                        Submission details                NaN
# 2                             Submission ID  Submission method
# 3                                       NP1              Email
# 4                                       NP1              Email
# 5                                       NaN                NaN
# 6                                       NaN                NaN
# 7                                       NaN                NaN
# 8                                       NaN                NaN
# 9                                       NaN                NaN
# 10                                      NaN                NaN
# 11                                      NaN                NaN
# 12                                      NaN                NaN
# 13                                      NaN                NaN
# 14                                      NaN                NaN
# 15                                      NaN                NaN
# 16                                      NaN                NaN
# 17                                      NaN                NaN
# 18                                      NaN                NaN
# 19                                      NaN                NaN
#
#             Unnamed: 4           Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                  NaN                  NaN        NaN        NaN
# 1                  NaN                  NaN        NaN        NaN
# 2   Link to submission                 Date   Proforma  Issue no.
# 3          RM ref no.   2016-02-10 00:00:00         No          1
# 4          RM ref no.   2016-02-10 00:00:00         No          2
# 5                  NaN                  NaN        NaN        NaN
# 6                  NaN                  NaN        NaN        NaN
# 7                  NaN                  NaN        NaN        NaN
# 8                  NaN                  NaN        NaN        NaN
# 9                  NaN                  NaN        NaN        NaN
# 10                 NaN                  NaN        NaN        NaN
# 11                 NaN                  NaN        NaN        NaN
# 12                 NaN                  NaN        NaN        NaN
# 13                 NaN                  NaN        NaN        NaN
# 14                 NaN                  NaN        NaN        NaN
# 15                 NaN                  NaN        NaN        NaN
# 16                 NaN                  NaN        NaN        NaN
# 17                 NaN                  NaN        NaN        NaN
# 18                 NaN                  NaN        NaN        NaN
# 19                 NaN                  NaN        NaN        NaN
#
#                                            Unnamed: 8              Unnamed: 9  \
# 0                                                 NaN                     NaN
# 1                                      Issue analysis                     NaN
# 2                                       Issue Summary               Key Issue
# 3   Concerned about loss of character protection a...  Character and heritage
# 4                       Support new park along river               Open space
# 5                                                 NaN                     NaN
# 6                                                 NaN                     NaN
# 7                                                 NaN                     NaN
# 8                                                 NaN                     NaN
# 9                                                 NaN                     NaN
# 10                                                NaN                     NaN
# 11                                                NaN                     NaN
# 12                                                NaN                     NaN
# 13                                                NaN                     NaN
# 14                                                NaN                     NaN
# 15                                                NaN                     NaN
# 16                                                NaN                     NaN
# 17                                                NaN                     NaN
# 18                                                NaN                     NaN
# 19                                                NaN                     NaN
#
#     ... Unnamed: 16359 Unnamed: 16360 Unnamed: 16361 Unnamed: 16362  \
# 0   ...            NaN            NaN            NaN            NaN
# 1   ...            NaN            NaN            NaN            NaN
# 2   ...    Column16345    Column16346    Column16347    Column16348
# 3   ...            NaN            NaN            NaN            NaN
# 4   ...            NaN            NaN            NaN            NaN
# 5   ...            NaN            NaN            NaN            NaN
# 6   ...            NaN            NaN            NaN            NaN
# 7   ...            NaN            NaN            NaN            NaN
# 8   ...            NaN            NaN            NaN            NaN
# 9   ...            NaN            NaN            NaN            NaN
# 10  ...            NaN            NaN            NaN            NaN
# 11  ...            NaN            NaN            NaN            NaN
# 12  ...            NaN            NaN            NaN            NaN
# 13  ...            NaN            NaN            NaN            NaN
# 14  ...            NaN            NaN            NaN            NaN
# 15  ...            NaN            NaN            NaN            NaN
# 16  ...            NaN            NaN            NaN            NaN
# 17  ...            NaN            NaN            NaN            NaN
# 18  ...            NaN            NaN            NaN            NaN
# 19  ...            NaN            NaN            NaN            NaN
#
#    Unnamed: 16363 Unnamed: 16364 Unnamed: 16365  Unnamed: 16366  \
# 0             NaN            NaN            NaN             NaN
# 1             NaN            NaN            NaN             NaN
# 2     Column16349    Column16350    Column16351     Column16352
# 3             NaN            NaN            NaN             NaN
# 4             NaN            NaN            NaN             NaN
# 5             NaN            NaN            NaN             NaN
# 6             NaN            NaN            NaN             NaN
# 7             NaN            NaN            NaN             NaN
# 8             NaN            NaN            NaN             NaN
# 9             NaN            NaN            NaN             NaN
# 10            NaN            NaN            NaN             NaN
# 11            NaN            NaN            NaN             NaN
# 12            NaN            NaN            NaN             NaN
# 13            NaN            NaN            NaN             NaN
# 14            NaN            NaN            NaN             NaN
# 15            NaN            NaN            NaN             NaN
# 16            NaN            NaN            NaN             NaN
# 17            NaN            NaN            NaN             NaN
# 18            NaN            NaN            NaN             NaN
# 19            NaN            NaN            NaN             NaN
#
#     Unnamed: 16367  Unnamed: 16368
# 0              NaN             NaN
# 1              NaN             NaN
# 2      Column16353     Column16354
# 3              NaN             NaN
# 4              NaN             NaN
# 5              NaN             NaN
# 6              NaN             NaN
# 7              NaN             NaN
# 8              NaN             NaN
# 9              NaN             NaN
# 10             NaN             NaN
# 11             NaN             NaN
# 12             NaN             NaN
# 13             NaN             NaN
# 14             NaN             NaN
# 15             NaN             NaN
# 16             NaN             NaN
# 17             NaN             NaN
# 18             NaN             NaN
# 19             NaN             NaN
#
# [20 rows x 16369 columns]

# %%
def preprocess_text(doc):
    if(not(pd.isnull(doc))):
        doc = doc.strip().replace("\n","")
    return doc

# %%
text['Original text'] = text['Original text'].apply(preprocess_text) 
text['Segmented text'] = text['Segmented text'].apply(preprocess_text)

# %%
def tokenized_text(data):
    return tokenizer.encode(data, return_tensors="pt", max_length= 1000).to(device)

# %%
for i, row in text.iterrows():
    temp = row['Original text']
    if(not(pd.isnull(temp))):
        temp = "summarize: "+ temp
        temp = tokenized_text(temp)
        t = model.generate(temp,
                           num_beams=4,
                           no_repeat_ngram_size=2,
                           min_length=30,
                           max_length=900,
                           early_stopping=True)
        text.at[i, 'Original summ'] = tokenizer.decode(t[0], skip_special_tokens=True)

# %%
text[:20]
# Out:
#                                         Original text  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   "believe there are a number of issues that nee...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  a resident of and a frequent traveller on the ...
# 11  I have just built a new home in Road, Kedron. ...
# 12  I would like to express my concerns with the p...
# 13                                                NaN
# 14  watched my son who lives at fill out the onlin...
# 15  its heading in the right direction. completely...
# 16                                                NaN
# 17  I am amazed and disappointed that after all th...
# 18                                                NaN
# 19                                                NaN
#
#                                        Segmented text  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   1) mechanisms• is surrounded by high levels of...
# 6   2) • is identified within Footprint, although ...
# 7   3) and • nature conservation values bordering ...
# 8   6) and • area is identified as having high to ...
# 9   4) • and improve the main waterway corridor th...
# 10  a resident of and a frequent traveller on the ...
# 11  I have just built a new home in Road, Kedron. ...
# 12  I would like to express my concerns with the p...
# 13  Road is already chaotic for us at the moment a...
# 14  watched my son who lives at fill out the onlin...
# 15  its heading in the right direction. completely...
# 16  lacks infrastructure in these areas. would be ...
# 17  I am amazed and disappointed that after all th...
# 18  is a copy of a statement I prepared in for par...
# 19  UPPER KEDRON DEVELOPMENT a resident of for 15 ...
#
#    Example structure of outputs of analysis         Unnamed: 3  \
# 0                                       NaN                NaN
# 1                        Submission details                NaN
# 2                             Submission ID  Submission method
# 3                                       NP1              Email
# 4                                       NP1              Email
# 5                                       NaN                NaN
# 6                                       NaN                NaN
# 7                                       NaN                NaN
# 8                                       NaN                NaN
# 9                                       NaN                NaN
# 10                                      NaN                NaN
# 11                                      NaN                NaN
# 12                                      NaN                NaN
# 13                                      NaN                NaN
# 14                                      NaN                NaN
# 15                                      NaN                NaN
# 16                                      NaN                NaN
# 17                                      NaN                NaN
# 18                                      NaN                NaN
# 19                                      NaN                NaN
#
#             Unnamed: 4           Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                  NaN                  NaN        NaN        NaN
# 1                  NaN                  NaN        NaN        NaN
# 2   Link to submission                 Date   Proforma  Issue no.
# 3          RM ref no.   2016-02-10 00:00:00         No          1
# 4          RM ref no.   2016-02-10 00:00:00         No          2
# 5                  NaN                  NaN        NaN        NaN
# 6                  NaN                  NaN        NaN        NaN
# 7                  NaN                  NaN        NaN        NaN
# 8                  NaN                  NaN        NaN        NaN
# 9                  NaN                  NaN        NaN        NaN
# 10                 NaN                  NaN        NaN        NaN
# 11                 NaN                  NaN        NaN        NaN
# 12                 NaN                  NaN        NaN        NaN
# 13                 NaN                  NaN        NaN        NaN
# 14                 NaN                  NaN        NaN        NaN
# 15                 NaN                  NaN        NaN        NaN
# 16                 NaN                  NaN        NaN        NaN
# 17                 NaN                  NaN        NaN        NaN
# 18                 NaN                  NaN        NaN        NaN
# 19                 NaN                  NaN        NaN        NaN
#
#                                            Unnamed: 8              Unnamed: 9  \
# 0                                                 NaN                     NaN
# 1                                      Issue analysis                     NaN
# 2                                       Issue Summary               Key Issue
# 3   Concerned about loss of character protection a...  Character and heritage
# 4                       Support new park along river               Open space
# 5                                                 NaN                     NaN
# 6                                                 NaN                     NaN
# 7                                                 NaN                     NaN
# 8                                                 NaN                     NaN
# 9                                                 NaN                     NaN
# 10                                                NaN                     NaN
# 11                                                NaN                     NaN
# 12                                                NaN                     NaN
# 13                                                NaN                     NaN
# 14                                                NaN                     NaN
# 15                                                NaN                     NaN
# 16                                                NaN                     NaN
# 17                                                NaN                     NaN
# 18                                                NaN                     NaN
# 19                                                NaN                     NaN
#
#     ... Unnamed: 16360 Unnamed: 16361 Unnamed: 16362 Unnamed: 16363  \
# 0   ...            NaN            NaN            NaN            NaN
# 1   ...            NaN            NaN            NaN            NaN
# 2   ...    Column16346    Column16347    Column16348    Column16349
# 3   ...            NaN            NaN            NaN            NaN
# 4   ...            NaN            NaN            NaN            NaN
# 5   ...            NaN            NaN            NaN            NaN
# 6   ...            NaN            NaN            NaN            NaN
# 7   ...            NaN            NaN            NaN            NaN
# 8   ...            NaN            NaN            NaN            NaN
# 9   ...            NaN            NaN            NaN            NaN
# 10  ...            NaN            NaN            NaN            NaN
# 11  ...            NaN            NaN            NaN            NaN
# 12  ...            NaN            NaN            NaN            NaN
# 13  ...            NaN            NaN            NaN            NaN
# 14  ...            NaN            NaN            NaN            NaN
# 15  ...            NaN            NaN            NaN            NaN
# 16  ...            NaN            NaN            NaN            NaN
# 17  ...            NaN            NaN            NaN            NaN
# 18  ...            NaN            NaN            NaN            NaN
# 19  ...            NaN            NaN            NaN            NaN
#
#    Unnamed: 16364 Unnamed: 16365 Unnamed: 16366  Unnamed: 16367  \
# 0             NaN            NaN            NaN             NaN
# 1             NaN            NaN            NaN             NaN
# 2     Column16350    Column16351    Column16352     Column16353
# 3             NaN            NaN            NaN             NaN
# 4             NaN            NaN            NaN             NaN
# 5             NaN            NaN            NaN             NaN
# 6             NaN            NaN            NaN             NaN
# 7             NaN            NaN            NaN             NaN
# 8             NaN            NaN            NaN             NaN
# 9             NaN            NaN            NaN             NaN
# 10            NaN            NaN            NaN             NaN
# 11            NaN            NaN            NaN             NaN
# 12            NaN            NaN            NaN             NaN
# 13            NaN            NaN            NaN             NaN
# 14            NaN            NaN            NaN             NaN
# 15            NaN            NaN            NaN             NaN
# 16            NaN            NaN            NaN             NaN
# 17            NaN            NaN            NaN             NaN
# 18            NaN            NaN            NaN             NaN
# 19            NaN            NaN            NaN             NaN
#
#     Unnamed: 16368                                      Original summ
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2      Column16354                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# 5              NaN  "believe there are a number of issues that nee...
# 6              NaN                                                NaN
# 7              NaN                                                NaN
# 8              NaN                                                NaN
# 9              NaN                                                NaN
# 10             NaN  new housing developments in are complete, the ...
# 11             NaN  big problem for me is that I cannot get any in...
# 12             NaN  road is already chaotic for us at peak times -...
# 13             NaN                                                NaN
# 14             NaN  questions have skirted around the main issue w...
# 15             NaN  lacks infrastructure in these areas. would be ...
# 16             NaN                                                NaN
# 17             NaN  UPPER KEDRON DEVELOPMENT is a resident of for ...
# 18             NaN                                                NaN
# 19             NaN                                                NaN
#
# [20 rows x 16370 columns]

# %%
(text.loc[12,'Original text'])
# Out:
# 'I would like to express my concerns with the planned expansion of the ferny grove and upper kedron precinct and increased population density. road is already chaotic for us at the moment at peak times - taking over 30 mins just from ferny grove to at times. of the train stations alongside the ferny grove line have space for car park after 7:30am, and whenever there is a fault, which now seems to happen once every week, buses from to ferny grove can take over 1 hr to get there. need better transport solutions immediately before any more houses are made available....'

# %%
(text.loc[12,'Original summ'])
# Out:
# 'road is already chaotic for us at peak times - taking over 30 mins just from ferny grove. of the train stations alongside the line have space for car park after 7:30am, and whenever there is a fault, buses can take over 1 hr to get there. need better transport solutions immediately before any more houses are made available...'

# %%
for i, row in text.iterrows():
    tempp = row['Segmented text']
    if(not(pd.isnull(tempp))):
        tempp = "summarize: "+ tempp
        tempp = tokenized_text(tempp)
        tt = model.generate(tempp,
                            num_beams=4,
                            no_repeat_ngram_size=2,
                            min_length=30,
                            max_length=300,
                            early_stopping=True)
        text.at[i, 'seg summ'] = tokenizer.decode(tt[0], skip_special_tokens=True)

# %%
(text.loc[15,'Segmented text'])
# Out:
# 'its heading in the right direction. completely understand there are time frames, would like to see the upgrade in infrastructure happen fast.. with new residential development taking place in it is imperative that there are options for young families to shop and dine in a modern complex.'

# %%
(text.loc[15,'seg summ'])
# Out:
# 'new residential development taking place in it is imperative that there are options for young families to shop and dine in a modern complex. the development is currently in the right direction and will be able to be upgraded to the next level in time frame.'

# %%
text = text[['Original text','Original summ','Segmented text','seg summ']]

# %%
text[4:24]
# Out:
#                                         Original text  \
# 4                                                 NaN
# 5   "believe there are a number of issues that nee...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  a resident of and a frequent traveller on the ...
# 11  I have just built a new home in Road, Kedron. ...
# 12  I would like to express my concerns with the p...
# 13                                                NaN
# 14  watched my son who lives at fill out the onlin...
# 15  its heading in the right direction. completely...
# 16                                                NaN
# 17  I am amazed and disappointed that after all th...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  I attended a one on one with a planner at and ...
# 22                                                NaN
# 23                                                NaN
#
#                                         Original summ  \
# 4                                                 NaN
# 5   "believe there are a number of issues that nee...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  new housing developments in are complete, the ...
# 11  big problem for me is that I cannot get any in...
# 12  road is already chaotic for us at peak times -...
# 13                                                NaN
# 14  questions have skirted around the main issue w...
# 15  lacks infrastructure in these areas. would be ...
# 16                                                NaN
# 17  UPPER KEDRON DEVELOPMENT is a resident of for ...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  the new estates are opening at and more people...
# 22                                                NaN
# 23                                                NaN
#
#                                        Segmented text  \
# 4                                                 NaN
# 5   1) mechanisms• is surrounded by high levels of...
# 6   2) • is identified within Footprint, although ...
# 7   3) and • nature conservation values bordering ...
# 8   6) and • area is identified as having high to ...
# 9   4) • and improve the main waterway corridor th...
# 10  a resident of and a frequent traveller on the ...
# 11  I have just built a new home in Road, Kedron. ...
# 12  I would like to express my concerns with the p...
# 13  Road is already chaotic for us at the moment a...
# 14  watched my son who lives at fill out the onlin...
# 15  its heading in the right direction. completely...
# 16  lacks infrastructure in these areas. would be ...
# 17  I am amazed and disappointed that after all th...
# 18  is a copy of a statement I prepared in for par...
# 19  UPPER KEDRON DEVELOPMENT a resident of for 15 ...
# 20  parcel of land contains dormitory areas and a ...
# 21  I  attended a one on one with a planner at and...
# 22  I use this road quite regularly to visit my si...
# 23  road in its present state in just wide enough ...
#
#                                              seg summ
# 4                                                 NaN
# 5   surrounded by high levels of protection for co...
# 6   zoned rural and special facilities have signif...
# 7   ecosystem services value associated with water...
# 8   sediment entering the waterways will impact al...
# 9   a 100m buffer (minimum)on either side of the w...
# 10  new housing developments in are complete, the ...
# 11  big problem for me is that I cannot get any in...
# 12  the expansion of the ferny grove and upper ked...
# 13  buses from to ferny grove can take over 1 hr t...
# 14  questions have skirted around the main issue w...
# 15  new residential development taking place in it...
# 16  a shopping complex and lake/parklands similar ...
# 17  project of this magnitude will clearly impose ...
# 18  this area needs an upgrade of a few intersecti...
# 19  peak times traffic congestion is heavy within ...
# 20  parcel of land contains dormitory areas and a ...
# 21  first concern is when will be upgraded as my p...
# 22  the new estates are opening at and more people...
# 23  road in its present state in just wide enough ...

# %%
text[4:].to_csv('Summary_v12.csv', index=False)
